# %%
import os
os.environ["KERAS_BACKEND"] = "jax"
import keras
from keras import layers
import numpy as np
import xarray as xr
import zarr
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import random
import jax
import tensorflow as tf
from tqdm import tqdm
import jax.numpy as jnp
from jax import grad, jit, vmap
from utils.clim_loss_vit import custom_loss
#from utils.clim_loss import ClimateDownscalingLoss

# Set seed for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
jax.config.update('jax_enable_x64', True)
jax.random.PRNGKey(SEED)


# Set the working directory
os.chdir('/data/keeling/a/ad87/downscale')

# %% [markdown]
# ### Data Handling: Load and Resample Data
# We will load the CMIP6 data and the GMFD observational data. We’ll resample the GMFD data to the CMIP6 resolution (e.g., ~100 km) to use as the target during training.

# %%
# Load the CMIP6 raw data (predictor variables)
cmip6_tas_path = '/data/cristi/a/cristi/downscaled_data/cmip6/raw/zarr/RO_CMIP6_raw/CNRM-ESM2-1/historical/r1i1p1f2/tas/tas_day_CNRM-ESM2-1_historical_r1i1p1f2_gr_1950_2014_rou.zarr'
cmip6_tas = xr.open_zarr(cmip6_tas_path)

cmip6_pr_path = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/historical/r1i1p1f2/pr/pr_day_CNRM-ESM2-1_historical_r1i1p1f2_gr_1950_2014_rou.zarr'
cmip6_pr = xr.open_zarr(cmip6_pr_path)

cmip6_psl_path = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/historical/r1i1p1f2/psl/psl_day_CNRM-ESM2-1_historical_r1i1p1f2_gr_1950_2014_rou.zarr'
cmip6_psl = xr.open_zarr(cmip6_psl_path)

# Load the GMFD reference observational data (target variable)
gmfd_data_path = '/data/keeling/a/cristi/a/downscaled_data/gmfd/ncs/ro'
gmfd_tas_files = [f'{gmfd_data_path}/tas_daily_ro_{year}.nc' for year in range(1950, 2015)]
gmfd_tas = xr.open_mfdataset(gmfd_tas_files, combine='by_coords')
gmfd_pr_files = [f'{gmfd_data_path}/prcp_daily_ro_{year}.nc' for year in range(1950, 2015)]
gmfd_pr = xr.open_mfdataset(gmfd_pr_files, combine='by_coords')
gmfd_pr['prcp'] = gmfd_pr['prcp'] * 86400

# Resample  CMIP6 to GMFD resolution (~25 km)
target_lat = gmfd_tas.lat
target_lon = gmfd_tas.lon
cmip6_high_tas = cmip6_tas['tas'].interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_high_pr = cmip6_pr['pr'].interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_high_pr = cmip6_high_pr.where(cmip6_high_pr > 0, 0)  # Set negative values to zero
cmip6_high_pr = cmip6_high_pr * 86400
cmip6_high_psl = cmip6_psl['psl'].interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})

cmip6_high_tas['time'] = cmip6_high_tas['time'].dt.floor('D')
cmip6_high_pr['time'] = cmip6_high_pr['time'].dt.floor('D')

# %% [markdown]
# #### Transform (pr) and normalize

# %%
# Apply the log1p transformation to the 'prcp' variable
cmip6_high_pr_log1p = cmip6_high_pr.copy()  # Make a copy to avoid modifying the original dataset
# Apply the log1p transformation to the precipitation data
cmip6_high_pr_log1p = xr.apply_ufunc(
    np.log1p,                 # The function to apply (log1p)
   cmip6_high_pr,               # The data variable to transform
    dask="parallelized",      # Enable parallel computations with Dask
    output_dtypes=[float]     # Specify output data type
)

# Apply the log1p transformation to the 'prcp' variable
gmfd_pr_log1p = gmfd_pr.copy()  # Make a copy to avoid modifying the original dataset
# Apply the log1p transformation to the precipitation data
gmfd_pr_log1p['prcp'] = xr.apply_ufunc(
    np.log1p,                 # The function to apply (log1p)
    gmfd_pr['prcp'],               # The data variable to transform
    dask="parallelized",      # Enable parallel computations with Dask
    output_dtypes=[float]     # Specify output data type
)

# %%
def normalize(data):
    min_val = data.min()
    max_val = data.max()
    return (data - min_val) / (max_val - min_val)

cmip6_tas_norm = normalize(cmip6_high_tas)
cmip6_psl_norm = normalize(cmip6_high_psl)
cmip6_pr_norm = normalize(cmip6_high_pr_log1p)
gmfd_tas_norm = normalize(gmfd_tas['tas'])
gmfd_pr_norm = normalize(gmfd_pr_log1p['prcp'])


# Convert data to NumPy arrays for use in Keras
cmip6_train_tas = cmip6_tas_norm.values
cmip6_train_psl = cmip6_psl_norm.values
cmip6_train_pr = cmip6_pr_norm.values
gmfd_train_pr = gmfd_pr_norm.values
gmfd_train_tas = gmfd_tas_norm.values

# %% [markdown]
# #### Compute residuals

# %%
import xarray as xr

res_tas = gmfd_train_tas  - cmip6_train_tas
res_pr = gmfd_train_pr  - cmip6_train_pr

# %%
plt.imshow(res_pr[100, :,:], origin='lower', cmap='viridis')

# %% [markdown]
# #### Split the data
# Train set: The first portion of the time period (e.g., 60% of the time series).
# Validation set: The next portion of the time series (e.g., the following 20% of the time series).
# Test set: The final portion of the time series (e.g., the last 20%):

# %%
import pandas as pd
index_2004 = int(np.where(cmip6_tas_norm.time.values == pd.to_datetime('2004-12-31'))[0][0])
index_2009 = int(np.where(cmip6_tas_norm.time.values == pd.to_datetime('2009-12-31'))[0][0])

# %%
# Reshape data to add the channel dimension
cmip6_train_tas_reshaped = cmip6_train_tas[..., np.newaxis]
cmip6_train_pr_reshaped = cmip6_train_psl[..., np.newaxis]
cmip6_train_slp_reshaped = cmip6_train_psl[..., np.newaxis]


# Concatenate the reshaped arrays along the last axis
cmip6_train_combined = np.concatenate((cmip6_train_tas_reshaped,cmip6_train_pr_reshaped, cmip6_train_slp_reshaped), axis=-1)

gmfd_train_tas_reshaped = gmfd_train_tas[..., np.newaxis]
gmfd_train_pr_reshaped = gmfd_train_pr[..., np.newaxis]

gmfd_train_combined = np.concatenate((gmfd_train_tas_reshaped,gmfd_train_pr_reshaped), axis=-1)

res_tas_reshaped = res_tas[..., np.newaxis]
res_pr_reshaped = res_pr[..., np.newaxis]

res_train_combined = np.concatenate((res_tas_reshaped, res_pr_reshaped), axis=-1)

# %%
# Split the data while preserving the temporal structure
X_train = cmip6_train_combined[:index_2004]
y_train = gmfd_train_combined[:index_2004]
res_train = res_train_combined[:index_2004]

X_val = cmip6_train_combined[index_2004:index_2009]
y_val = gmfd_train_combined[index_2004:index_2009]
res_val = res_train_combined[index_2004:index_2009]

X_test = cmip6_train_combined[index_2009:]
y_test = gmfd_train_combined[index_2009:]
res_test = res_train_combined[index_2009:]


# # Reshape X data to include the temporal dimension
# X_train = np.expand_dims(X_train, axis=1)
# X_val = np.expand_dims(X_val, axis=1)
# X_test = np.expand_dims(X_test, axis=1)

# # Reshape y data to include the temporal dimension
# y_train = np.expand_dims(y_train, axis=1)
# y_val = np.expand_dims(y_val, axis=1)
# y_test = np.expand_dims(y_test, axis=1)

# # Reshape y data to include the temporal dimension
# res_train = np.expand_dims(res_train, axis=1)
# res_val = np.expand_dims(res_val, axis=1)
# res_test = np.expand_dims(res_test, axis=1)

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
print(res_train.shape)
print(res_val.shape)
print(res_test.shape)
# Out:
# (20088, 42, 97, 3)
# (1826, 42, 97, 3)
# (1827, 42, 97, 3)
# (20088, 42, 97, 2)
# (1826, 42, 97, 2)
# (1827, 42, 97, 2)

# %% [markdown]
# #### Create temporal sequences

# %%
def create_temporal_sequences_centered(data, window_size):
    total_seq_length = 2 * window_size + 1
    sequences = []
    
    # For all time points
    for i in range(len(data)):
        sequence = np.zeros((total_seq_length,) + data.shape[1:])
        
        # Handle past values
        for j in range(window_size):
            if i - j >= 0:  # If we have data for this past point
                sequence[window_size - j] = data[i - j]
            else:  # If we don't have data, use the earliest available
                sequence[window_size - j] = data[0]
        
        # Current value
        sequence[window_size] = data[i]
        
        # Handle future values
        for j in range(window_size):
            if i + j + 1 < len(data):  # If we have data for this future point
                sequence[window_size + j + 1] = data[i + j + 1]
            else:  # If we don't have data, use the last available
                sequence[window_size + j + 1] = data[-1]
        
        sequences.append(sequence)
    
    return np.array(sequences)

window_size = 3

# %%
X_train_seq = create_temporal_sequences_centered(X_train, window_size)  
X_val_seq = create_temporal_sequences_centered(X_val, window_size)      
X_test_seq = create_temporal_sequences_centered(X_test, window_size)     
y_train_seq = create_temporal_sequences_centered(y_train, window_size) 
y_val_seq = create_temporal_sequences_centered(y_val, window_size)     
y_test_seq = create_temporal_sequences_centered(y_test, window_size)   

res_train_seq = create_temporal_sequences_centered(res_train, window_size) 
res_val_seq = create_temporal_sequences_centered(res_val, window_size)     
res_test_seq = create_temporal_sequences_centered(res_test, window_size) 

print("X_train shape:", X_train_seq.shape)
print("X_val shape:", X_val_seq.shape)
print("y_train shape:", y_train_seq.shape)
print("y_val shape:", y_val_seq.shape)
print("res_train shape:", res_train_seq.shape)
print("res_val shape:", res_val_seq.shape)
# Out:
# X_train shape: (20088, 7, 42, 97, 3)
# X_val shape: (1826, 7, 42, 97, 3)
# y_train shape: (20088, 7, 42, 97, 2)
# y_val shape: (1826, 7, 42, 97, 2)
# res_train shape: (20088, 7, 42, 97, 2)
# res_val shape: (1826, 7, 42, 97, 2)

# %% [markdown]
# #### Build the VIT-transformenrs (Keras with JAX Backend)

# %%
from keras import ops
from keras.layers import (
    Input, Dense, Dropout, MultiHeadAttention, LayerNormalization,
    Add, Conv3D, Reshape, TimeDistributed, Layer
)
from keras.models import Model, Sequential  # Added Sequential import
from keras import regularizers
from keras.saving import register_keras_serializable

# **Fourier Positional Encoding Layer** (No changes)
@register_keras_serializable()
class FourierPositionalEncoding(Layer):
    def __init__(self, embed_dim, max_freq=10, **kwargs):
        """
        Fourier positional encoding for spatial and temporal positions.
        Args:
            embed_dim: The dimension of the embeddings.
            max_freq: The maximum frequency for encoding.
        """
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.max_freq = max_freq

    def call(self, inputs):
        """
        Compute Fourier positional encodings and add them to the inputs.
        Args:
            inputs: Input tensor of shape (batch_size, seq_len, embed_dim).
        Returns:
            Tensor with Fourier positional encodings added.
        """
        batch_size, seq_len, embed_dim = ops.shape(inputs)

        # Generate positional values (normalized between 0 and 1)
        positions = ops.linspace(0.0, 1.0, seq_len)

        # Generate frequency bands
        freq_bands = ops.power(2.0, ops.linspace(0.0, self.max_freq, self.embed_dim // 2))

        # Compute Fourier features
        encodings = ops.matmul(ops.expand_dims(positions, axis=-1), ops.expand_dims(freq_bands, axis=0))  # seq_len x (embed_dim // 2)
        sin_encodings = ops.sin(encodings)
        cos_encodings = ops.cos(encodings)

        # Concatenate sine and cosine encodings
        positional_encodings = ops.concatenate([sin_encodings, cos_encodings], axis=-1)  # seq_len x embed_dim
        positional_encodings = ops.expand_dims(positional_encodings, axis=0)  # Add batch dimension
        positional_encodings = ops.broadcast_to(positional_encodings, [batch_size, seq_len, embed_dim])

        # Add positional encodings to inputs
        return inputs + positional_encodings

    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "max_freq": self.max_freq
        })
        return config

# **Residual Multi-Scale Patch Embedding Layer** (Modified num_scales handling)
@register_keras_serializable()
class ResidualMultiScalePatchEmbedding(Layer):
    def __init__(self, patch_size, embed_dim, num_scales=3, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size
        self.embed_dim = embed_dim
        self.num_scales = num_scales

    def build(self, input_shape):
        self.convs = [
            Conv3D(
                filters=self.embed_dim // self.num_scales,
                kernel_size=(k, k, k),
                strides=self.patch_size,
                padding='same',
                name=f"scale_{k}x{k}x{k}"
            )
            for k in range(3, 3 + self.num_scales)  # Dynamic kernel sizes
        ]
        self.fusion = Conv3D(
            filters=self.embed_dim,
            kernel_size=1,
            strides=1,
            padding="same",
            name="multi_scale_fusion"
        )
        self.residual_proj = Conv3D(
            filters=self.embed_dim,
            kernel_size=1,
            strides=self.patch_size,
            padding="same",
            name="residual_projection"
        )

    def call(self, x):
        batch_size = ops.shape(x)[0]
        multi_scale_features = [conv(x) for conv in self.convs]
        combined_features = ops.concatenate(multi_scale_features, axis=-1)
        fused_features = self.fusion(combined_features)
        residual = self.residual_proj(x)
        fused_features += residual
        _, t, h, w, c = ops.shape(fused_features)
        return ops.reshape(fused_features, (batch_size, t * h * w, c))

    def get_config(self):
        config = super().get_config()
        config.update({
            "patch_size": self.patch_size,
            "embed_dim": self.embed_dim,
            "num_scales": self.num_scales
        })
        return config

# **Spatial-Temporal Attention Block** (Simplified with unified attention)
@register_keras_serializable()
class SpatialTemporalAttentionBlock(Layer):
    def __init__(self, embed_dim, num_heads, mlp_dim, dropout, weight_decay, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.mlp_dim = mlp_dim
        self.dropout = dropout
        self.weight_decay = weight_decay

    def build(self, input_shape):
        # Unified Spatial-Temporal Attention
        self.attention = MultiHeadAttention(
            num_heads=self.num_heads,
            key_dim=self.embed_dim // self.num_heads,
            dropout=self.dropout
        )
        # Layer normalizations
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        # Feed-forward network (MLP)
        self.mlp = Sequential([
            Dense(self.mlp_dim, activation="gelu", kernel_regularizer=regularizers.L2(self.weight_decay)),
            Dropout(self.dropout),
            Dense(self.embed_dim, kernel_regularizer=regularizers.L2(self.weight_decay)),
            Dropout(self.dropout)
        ])

    def call(self, inputs):
        attn_output = self.attention(inputs, inputs)  # Unified attention
        x = Add()([inputs, attn_output])
        x = self.layernorm1(x)

        # Feed-forward network (MLP)
        mlp_output = self.mlp(x)
        return self.layernorm2(Add()([x, mlp_output]))

    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "mlp_dim": self.mlp_dim,
            "dropout": self.dropout,
            "weight_decay": self.weight_decay
        })
        return config

# **ViT Transformer** (Modified with dynamic output units and other improvements)
def vit_transformer(input_shape, patch_size, embed_dim, num_heads, transformer_layers, mlp_dim, dropout, weight_decay):
    inputs = Input(shape=input_shape)
    x = ResidualMultiScalePatchEmbedding(patch_size=patch_size, embed_dim=embed_dim, num_scales=3)(inputs)
    x = FourierPositionalEncoding(embed_dim=embed_dim, max_freq=10)(x)

    for _ in range(transformer_layers):
        x = SpatialTemporalAttentionBlock(
            embed_dim=embed_dim, num_heads=num_heads, mlp_dim=mlp_dim, dropout=dropout, weight_decay=weight_decay
        )(x)

    num_time_steps = input_shape[0]
    _, num_patches, embed_dim = ops.shape(x)
    num_spatial_patches = num_patches // num_time_steps
    x = Reshape((num_time_steps, num_spatial_patches * embed_dim))(x)

    x = TimeDistributed(Dense(units=mlp_dim // 2, activation="gelu", kernel_regularizer=regularizers.L2(weight_decay)))(x)
    x = TimeDistributed(Dropout(dropout))(x)
    total_units_per_timestep = input_shape[1] * input_shape[2] * 2 # change to 2
    x = TimeDistributed(Dense(units=total_units_per_timestep, activation="linear", kernel_regularizer=regularizers.L2(weight_decay)))(x)
    x = TimeDistributed(Reshape(target_shape=(input_shape[1], input_shape[2], 2)))(x)  #change to 2

    return Model(inputs, x)

# **Example Usage** (Adjusted input shape and num_scales)
input_shape = (7, 42, 97, 3)
patch_size = (1, 7, 7)

model = vit_transformer(
    input_shape=input_shape,
    patch_size=patch_size,
    embed_dim=320,
    num_heads=8,
    transformer_layers=6,
    mlp_dim=512,
    dropout=0.2,
    weight_decay=0.001
)

model.summary()
# Out:
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)      │ (None, 7, 42, 97, 3)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_multi_scale_patch_emb… │ (None, 588, 320)       │       172,366 │
# │ (ResidualMultiScalePatchEmbedd… │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fourier_positional_encoding_1   │ (None, 588, 320)       │             0 │
# │ (FourierPositionalEncoding)     │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ cast_1 (Cast)                   │ (None, 588, 320)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_temporal_attention_blo… │ (None, 588, 320)       │       740,672 │
# │ (SpatialTemporalAttentionBlock) │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_temporal_attention_blo… │ (None, 588, 320)       │       740,672 │
# │ (SpatialTemporalAttentionBlock) │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_temporal_attention_blo… │ (None, 588, 320)       │       740,672 │
# │ (SpatialTemporalAttentionBlock) │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_temporal_attention_blo… │ (None, 588, 320)       │       740,672 │
# │ (SpatialTemporalAttentionBlock) │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_temporal_attention_blo… │ (None, 588, 320)       │       740,672 │
# │ (SpatialTemporalAttentionBlock) │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_temporal_attention_blo… │ (None, 588, 320)       │       740,672 │
# │ (SpatialTemporalAttentionBlock) │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_2 (Reshape)             │ (None, 7, 26880)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_4              │ (None, 7, 256)         │     6,881,536 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_5              │ (None, 7, 256)         │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_6              │ (None, 7, 8148)        │     2,094,036 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_7              │ (None, 7, 42, 97, 2)   │             0 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,591,970 (51.85 MB)
#  Trainable params: 13,591,970 (51.85 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Train the model

# %%
import keras
from keras import ops
from keras.losses import Loss
from keras.saving import register_keras_serializable

@register_keras_serializable()
class ClimateDownscalingLoss(Loss):
    def __init__(self, 
                 spatial_weight_temp=1.0, gradient_weight_temp=0.5, temporal_weight_temp=0.3,
                 spatial_weight_precip=1.0, gradient_weight_precip=0.4, temporal_weight_precip=0.1,
                 mse_weight_temp=1.0, mse_weight_precip=0.5,  
                 observation_weight=1.0,
                 **kwargs):
        super().__init__(**kwargs)
        
        # Weights for temperature
        self.spatial_weight_temp = spatial_weight_temp
        self.gradient_weight_temp = gradient_weight_temp
        self.temporal_weight_temp = temporal_weight_temp
        self.mse_weight_temp = mse_weight_temp
        
        # Weights for precipitation
        self.spatial_weight_precip = spatial_weight_precip
        self.gradient_weight_precip = gradient_weight_precip
        self.temporal_weight_precip = temporal_weight_precip
        self.mse_weight_precip = mse_weight_precip

        self.observation_weight = observation_weight

        self.epsilon = 1e-6

    def call(self, y_true, y_pred, y_low_res=None):
        # Split channels (temperature and precipitation)
        y_true_temp = y_true[:, :, :, :, 0:1]
        y_pred_temp = y_pred[:, :, :, :, 0:1]
        y_true_precip = y_true[:, :, :, :, 1:2]
        y_pred_precip = y_pred[:, :, :, :, 1:2]

        # --- Observation Loss  ---
        observation_loss = (
            self.mse_weight_temp * ops.mean(ops.square(y_true_temp - y_pred_temp)) +
            self.mse_weight_precip * ops.mean(ops.square(y_true_precip - y_pred_precip))
        )

        # --- Regularization Loss (spatial, temporal) ---

        # Spatial Gradient Loss 
        def spatial_gradients(x):
            dy = x[:, :, 1:, :, :] - x[:, :, :-1, :, :]
            dx = x[:, :, :, 1:, :] - x[:, :, :, :-1, :]
            return dy, dx

        # Spatial gradients for temperature
        _, true_dx_temp = spatial_gradients(y_true_temp)
        _, pred_dx_temp = spatial_gradients(y_pred_temp)

        spatial_gradient_loss_temp = ops.mean(ops.square(true_dx_temp - pred_dx_temp)) + self.epsilon

        # Spatial gradients for precipitation
        _, true_dx_precip = spatial_gradients(y_true_precip)
        _, pred_dx_precip = spatial_gradients(y_pred_precip)

        spatial_gradient_loss_precip = ops.mean(ops.square(true_dx_precip - pred_dx_precip)) + self.epsilon

        # Temporal Gradient Loss
        def temporal_gradients(x):
            dt = x[:, 1:, :, :, :] - x[:, :-1, :, :, :]
            return dt

        # Temporal gradients for temperature
        true_dt_temp = temporal_gradients(y_true_temp)
        pred_dt_temp = temporal_gradients(y_pred_temp)

        temporal_gradient_loss_temp = ops.mean(ops.square(true_dt_temp - pred_dt_temp)) + self.epsilon

        # Temporal gradients for precipitation
        true_dt_precip = temporal_gradients(y_true_precip)
        pred_dt_precip = temporal_gradients(y_pred_precip)

        temporal_gradient_loss_precip = ops.mean(ops.square(true_dt_precip - pred_dt_precip)) + self.epsilon

        regularization_loss = (
            self.spatial_weight_temp * spatial_gradient_loss_temp
            + self.temporal_weight_temp * temporal_gradient_loss_temp
            + self.spatial_weight_precip * spatial_gradient_loss_precip
            + self.temporal_weight_precip * temporal_gradient_loss_precip
            # + other regularization terms... (add other constraints here)
        )

        # --- Total Loss ---
        total_loss = (
            self.observation_weight * observation_loss +
            regularization_loss
        )

        return total_loss

    def get_config(self):
        config = super().get_config()
        config.update({
            "spatial_weight_temp": self.spatial_weight_temp,
            "gradient_weight_temp": self.gradient_weight_temp,
            "temporal_weight_temp": self.temporal_weight_temp,
            "mse_weight_temp": self.mse_weight_temp,
            "spatial_weight_precip": self.spatial_weight_precip,
            "gradient_weight_precip": self.gradient_weight_precip,
            "temporal_weight_precip": self.temporal_weight_precip,
            "mse_weight_precip": self.mse_weight_precip,
            "observation_weight": self.observation_weight
        })
        return config

# %%
print(X_train_seq.shape)
# Out:
# (20088, 7, 42, 97, 3)

# %%
from keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint, TerminateOnNaN

# Model setup
input_shape = (7, 42, 97, 3)
patch_size = (7, 7, 7)


model = vit_transformer(
    input_shape=input_shape,
    patch_size=patch_size,
    embed_dim=320,
    num_heads=10,
    transformer_layers=8,
    mlp_dim=512,
    dropout=0.2,
    weight_decay=0.01
)


climate_loss = ClimateDownscalingLoss(
    spatial_weight_temp=0.1,
    gradient_weight_temp=0.05,
    temporal_weight_temp=0.05,
    spatial_weight_precip=0.5,
    gradient_weight_precip=0.05,
    temporal_weight_precip=0.05,
    mse_weight_temp=1.0,
    mse_weight_precip=1.0,
    observation_weight=0.01

)

# Learning rate schedule
initial_learning_rate = 1e-4
lr_schedule = tf.keras.optimizers.schedules.CosineDecayRestarts(
    initial_learning_rate=initial_learning_rate,
    first_decay_steps=50,
    t_mul=2.0,
    m_mul=0.8,
    alpha=1e-6
)

# Optimizer
optimizer = AdamW(learning_rate=lr_schedule, weight_decay=1e-5)


# Compile model
model.compile(
    optimizer=optimizer,
    loss=climate_loss,
    metrics=[
        tf.keras.metrics.MeanAbsoluteError(),
        tf.keras.metrics.RootMeanSquaredError()
    ]
)

# Callbacks
class LRLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f'\nLearning rate for epoch {epoch+1} is {lr}')

callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=20,
        restore_best_weights=True,
        min_delta=1e-4
    ),
    ModelCheckpoint(
        filepath='models/vit_transformer_best_model.keras',
        monitor='val_loss',
        save_best_only=True,
        save_weights_only=False,
        mode='min',
        verbose=1
    ),
    TerminateOnNaN(),
    LRLogger()
]

# Training
history = model.fit(
    X_train_seq, res_train_seq,
    validation_data=(X_val_seq, res_val_seq),
    epochs=500,
    batch_size=100,
    callbacks=callbacks,
    verbose=1,
    shuffle=False
)

# Print results
print("\nTraining completed.")
best_val_loss = min(history.history['val_loss'])
best_epoch = history.history['val_loss'].index(best_val_loss) + 1
print(f"Best validation loss: {best_val_loss:.6f} at epoch {best_epoch}")
# Out:
# Epoch 1/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - loss: 64.4563 - mean_absolute_error: 0.1181 - root_mean_squared_error: 0.1806
# Epoch 1: val_loss improved from inf to 48.14457, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 1 is 5.426925522174459e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 108s 434ms/step - loss: 64.4276 - mean_absolute_error: 0.1181 - root_mean_squared_error: 0.1806 - val_loss: 48.1446 - val_mean_absolute_error: 0.1040 - val_root_mean_squared_error: 0.1703
# Epoch 2/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 44.7726 - mean_absolute_error: 0.1030 - root_mean_squared_error: 0.1684
# Epoch 2: val_loss improved from 48.14457 to 37.61923, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 2 is 4.9094569322991516e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - loss: 44.7621 - mean_absolute_error: 0.1030 - root_mean_squared_error: 0.1684 - val_loss: 37.6192 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1701
# Epoch 3/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 34.4620 - mean_absolute_error: 0.1021 - root_mean_squared_error: 0.1681
# Epoch 3: val_loss improved from 37.61923 to 28.34619, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 3 is 1.5248888705660178e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 34.4498 - mean_absolute_error: 0.1021 - root_mean_squared_error: 0.1682 - val_loss: 28.3462 - val_mean_absolute_error: 0.1025 - val_root_mean_squared_error: 0.1699
# Epoch 4/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 27.8058 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1680
# Epoch 4: val_loss improved from 28.34619 to 24.93612, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 4 is 4.0501306224176195e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 27.8031 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1680 - val_loss: 24.9361 - val_mean_absolute_error: 0.1023 - val_root_mean_squared_error: 0.1699
# Epoch 5/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 22.9818 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1679
# Epoch 5: val_loss improved from 24.93612 to 18.14815, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 5 is 3.152162133166443e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - loss: 22.9732 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1679 - val_loss: 18.1481 - val_mean_absolute_error: 0.1022 - val_root_mean_squared_error: 0.1697
# Epoch 6/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 17.0946 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1678
# Epoch 6: val_loss improved from 18.14815 to 14.71603, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 6 is 1.60125104037724e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 17.0902 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1678 - val_loss: 14.7160 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1696
# Epoch 7/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 14.3070 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1677
# Epoch 7: val_loss improved from 14.71603 to 13.56150, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 7 is 3.1453006342440507e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - loss: 14.3055 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1677 - val_loss: 13.5615 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1696
# Epoch 8/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 13.4887 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1677
# Epoch 8: val_loss improved from 13.56150 to 12.27482, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 8 is 3.266193779704271e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 13.4879 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1677 - val_loss: 12.2748 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1695
# Epoch 9/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 11.3671 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1676
# Epoch 9: val_loss improved from 12.27482 to 8.95941, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 9 is 3.069473522007745e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 11.3629 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1676 - val_loss: 8.9594 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1694
# Epoch 10/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.3320 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1675
# Epoch 10: val_loss improved from 8.95941 to 6.69336, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 10 is 2.6527308738257055e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 8.3291 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1675 - val_loss: 6.6934 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1693
# Epoch 11/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.2780 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1674
# Epoch 11: val_loss improved from 6.69336 to 5.21019, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 11 is 2.0800388880191098e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - loss: 6.2762 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1674 - val_loss: 5.2102 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1692
# Epoch 12/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.9479 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1673
# Epoch 12: val_loss improved from 5.21019 to 4.28736, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 12 is 1.4394474055142478e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - loss: 4.9467 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1673 - val_loss: 4.2874 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1691
# Epoch 13/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.1328 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1673
# Epoch 13: val_loss improved from 4.28736 to 3.75790, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 13 is 8.294456308594458e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - loss: 4.1321 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1673 - val_loss: 3.7579 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1691
# Epoch 14/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.6783 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1672
# Epoch 14: val_loss improved from 3.75790 to 3.50062, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 14 is 3.438196839136412e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 3.6780 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1672 - val_loss: 3.5006 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1690
# Epoch 15/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.4710 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1672
# Epoch 15: val_loss improved from 3.50062 to 3.41819, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 15 is 5.723323806146566e-07
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 3.4709 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1672 - val_loss: 3.4182 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1690
# Epoch 16/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.4072 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1672
# Epoch 16: val_loss improved from 3.41819 to 3.02323, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 16 is 2.618696856044849e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - loss: 3.4069 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1672 - val_loss: 3.0232 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1690
# Epoch 17/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.7619 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1671
# Epoch 17: val_loss improved from 3.02323 to 2.07016, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 17 is 2.57667463877505e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 2.7607 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1671 - val_loss: 2.0702 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1688
# Epoch 18/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.8891 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1670
# Epoch 18: val_loss improved from 2.07016 to 1.41194, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 18 is 2.485516700056803e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 1.8883 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1670 - val_loss: 1.4119 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1687
# Epoch 19/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.2881 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1669
# Epoch 19: val_loss improved from 1.41194 to 0.96298, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 19 is 2.348761193384307e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 1.2875 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1669 - val_loss: 0.9630 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1686
# Epoch 20/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8792 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1668
# Epoch 20: val_loss improved from 0.96298 to 0.66018, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 20 is 2.171716070874381e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 0.8789 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1668 - val_loss: 0.6602 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1685
# Epoch 21/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6041 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1667
# Epoch 21: val_loss improved from 0.66018 to 0.45776, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 21 is 1.9612530633674507e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 0.6039 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1667 - val_loss: 0.4578 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1684
# Epoch 22/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4205 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1666
# Epoch 22: val_loss improved from 0.45776 to 0.32324, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 22 is 1.7255409648915592e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 0.4203 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1666 - val_loss: 0.3232 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1683
# Epoch 23/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2986 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1666
# Epoch 23: val_loss improved from 0.32324 to 0.23412, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 23 is 1.473728573637784e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 0.2984 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1666 - val_loss: 0.2341 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1682
# Epoch 24/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2178 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1665
# Epoch 24: val_loss improved from 0.23412 to 0.17514, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 24 is 1.215589595599534e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 0.2177 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1665 - val_loss: 0.1751 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1682
# Epoch 25/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1644 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1664
# Epoch 25: val_loss improved from 0.17514 to 0.13615, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 25 is 9.611432933882473e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - loss: 0.1643 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1665 - val_loss: 0.1361 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1681
# Epoch 26/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1291 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1664
# Epoch 26: val_loss improved from 0.13615 to 0.11049, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 26 is 7.20265604151183e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 0.1290 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1664 - val_loss: 0.1105 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1681
# Epoch 27/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1059 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1664
# Epoch 27: val_loss improved from 0.11049 to 0.09387, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 27 is 5.0230582044401325e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 0.1059 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1664 - val_loss: 0.0939 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1681
# Epoch 28/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0910 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1664
# Epoch 28: val_loss improved from 0.09387 to 0.08348, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 28 is 3.157237119934584e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - loss: 0.0910 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1664 - val_loss: 0.0835 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1680
# Epoch 29/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0818 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1664
# Epoch 29: val_loss improved from 0.08348 to 0.07750, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 29 is 1.6776117290387968e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 0.0818 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1664 - val_loss: 0.0775 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1680
# Epoch 30/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0767 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663
# Epoch 30: val_loss improved from 0.07750 to 0.07462, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 30 is 6.416113881041358e-07
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 0.0767 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663 - val_loss: 0.0746 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1680
# Epoch 31/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0744 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663
# Epoch 31: val_loss improved from 0.07462 to 0.07375, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 31 is 8.944683771787716e-08
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 0.0744 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663 - val_loss: 0.0737 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1680
# Epoch 32/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0731 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663
# Epoch 32: val_loss improved from 0.07375 to 0.05215, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 32 is 2.0963105691647365e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 0.0731 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663 - val_loss: 0.0522 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1680
# Epoch 33/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0430 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663
# Epoch 33: val_loss improved from 0.05215 to 0.02279, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 33 is 2.0870584551175573e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 0.0430 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663 - val_loss: 0.0228 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1679
# Epoch 34/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0192 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1662
# Epoch 34: val_loss improved from 0.02279 to 0.01121, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 34 is 2.0677050941890224e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 0.0192 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1662 - val_loss: 0.0112 - val_mean_absolute_error: 0.1022 - val_root_mean_squared_error: 0.1678
# Epoch 35/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0099 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1662
# Epoch 35: val_loss improved from 0.01121 to 0.00689, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 35 is 2.0384387368024972e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 0.0099 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1662 - val_loss: 0.0069 - val_mean_absolute_error: 0.1022 - val_root_mean_squared_error: 0.1677
# Epoch 36/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0065 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1661
# Epoch 36: val_loss improved from 0.00689 to 0.00538, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 36 is 1.9995440572421367e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 0.0065 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1661 - val_loss: 0.0054 - val_mean_absolute_error: 0.1022 - val_root_mean_squared_error: 0.1677
# Epoch 37/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0053 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1660
# Epoch 37: val_loss improved from 0.00538 to 0.00489, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 37 is 1.9513993846219854e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 0.0053 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1660 - val_loss: 0.0049 - val_mean_absolute_error: 0.1022 - val_root_mean_squared_error: 0.1676
# Epoch 38/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0049 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1660
# Epoch 38: val_loss improved from 0.00489 to 0.00474, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 38 is 1.894473022873178e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 0.0049 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1660 - val_loss: 0.0047 - val_mean_absolute_error: 0.1023 - val_root_mean_squared_error: 0.1675
# Epoch 39/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0048 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1659
# Epoch 39: val_loss improved from 0.00474 to 0.00470, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 39 is 1.8293186955447846e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 0.0048 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1659 - val_loss: 0.0047 - val_mean_absolute_error: 0.1023 - val_root_mean_squared_error: 0.1675
# Epoch 40/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0048 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1659
# Epoch 40: val_loss improved from 0.00470 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 40 is 1.7565701597267966e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - loss: 0.0048 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1659 - val_loss: 0.0047 - val_mean_absolute_error: 0.1023 - val_root_mean_squared_error: 0.1674
# Epoch 41/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1659
# Epoch 41: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 41 is 1.6769350414856865e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1659 - val_loss: 0.0047 - val_mean_absolute_error: 0.1023 - val_root_mean_squared_error: 0.1674
# Epoch 42/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1658
# Epoch 42: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 42 is 1.5911879527753634e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1658 - val_loss: 0.0047 - val_mean_absolute_error: 0.1023 - val_root_mean_squared_error: 0.1673
# Epoch 43/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1658
# Epoch 43: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 43 is 1.5001629567754267e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1658 - val_loss: 0.0047 - val_mean_absolute_error: 0.1023 - val_root_mean_squared_error: 0.1673
# Epoch 44/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1658
# Epoch 44: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 44 is 1.404745454946482e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1658 - val_loss: 0.0047 - val_mean_absolute_error: 0.1024 - val_root_mean_squared_error: 0.1673
# Epoch 45/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657
# Epoch 45: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 45 is 1.3058635747172479e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657 - val_loss: 0.0047 - val_mean_absolute_error: 0.1024 - val_root_mean_squared_error: 0.1672
# Epoch 46/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657
# Epoch 46: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 46 is 1.2044791415755545e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657 - val_loss: 0.0047 - val_mean_absolute_error: 0.1024 - val_root_mean_squared_error: 0.1672
# Epoch 47/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657
# Epoch 47: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 47 is 1.1015783233778255e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657 - val_loss: 0.0047 - val_mean_absolute_error: 0.1024 - val_root_mean_squared_error: 0.1672
# Epoch 48/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657
# Epoch 48: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 48 is 9.981620378799894e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657 - val_loss: 0.0047 - val_mean_absolute_error: 0.1024 - val_root_mean_squared_error: 0.1672
# Epoch 49/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1657
# Epoch 49: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 49 is 8.952362167959056e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1657 - val_loss: 0.0047 - val_mean_absolute_error: 0.1024 - val_root_mean_squared_error: 0.1672
# Epoch 50/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 50: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 50 is 7.938020210849407e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1024 - val_root_mean_squared_error: 0.1671
# Epoch 51/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 51: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 51 is 6.948461026447549e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1024 - val_root_mean_squared_error: 0.1671
# Epoch 52/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 52: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 52 is 5.9933100713393355e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1025 - val_root_mean_squared_error: 0.1671
# Epoch 53/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 53: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 53 is 5.081858112763584e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 10s 34ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1025 - val_root_mean_squared_error: 0.1671
# Epoch 54/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 54: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 54 is 4.222970857183999e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1025 - val_root_mean_squared_error: 0.1671
# Epoch 55/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 55: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 55 is 3.42500271343335e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1025 - val_root_mean_squared_error: 0.1671
# Epoch 56/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 56: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 56 is 2.695715529257211e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1025 - val_root_mean_squared_error: 0.1671
# Epoch 57/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 57: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 57 is 2.042203091707993e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1025 - val_root_mean_squared_error: 0.1671
# Epoch 58/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 58: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 58 is 1.4708221257750524e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1025 - val_root_mean_squared_error: 0.1671
#
# Training completed.
# Best validation loss: 0.004686 at epoch 58

# %%
import matplotlib.pyplot as plt

# Assuming 'history' is the result of model.fit()
plt.figure(figsize=(8, 4))

# Plotting the training and validation loss with log scale on y-axis
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

# Title and labels
plt.title('Training and Validation Loss Over Epochs (Log Scale)')
plt.xlabel('Epochs')
plt.ylabel('Loss (Log Scale)')

# Set y-axis to log scale
#plt.yscale('log')

# Optional: Set y-axis limits (adjust these as needed for your data)
#plt.ylim(0,1)  # Example: Set limits from 0.001 to 10

# Show legend
plt.legend()

# Add grid for clarity
plt.grid(which='both')  # Add grid for both major and minor ticks

# Show the plot
plt.show()

# %% [markdown]
# #### Evaluate the model on validation data

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
# Load the model

from keras.models import load_model

model_saved = load_model('models/vit_transformer_best_model.keras')

# %%
# Get the mean and std from the training set for denormalization
cmip6_high_tas_min = cmip6_high_tas.min().values
cmip6_high_tas_max = cmip6_high_tas.max().values
cmip6_high_pr_min = cmip6_high_pr_log1p.min().values
cmip6_high_pr_max = cmip6_high_pr_log1p.max().values

# Get the mean and std from the training set for denormalization
gmfd_min_tas = gmfd_tas['tas'].min().values
gmfd_max_tas = gmfd_tas['tas'].max().values
gmfd_min_pr = gmfd_pr_log1p['prcp'].min().values
gmfd_max_pr = gmfd_pr_log1p['prcp'].max().values


# Generate predictions on validation data
y_pred = model_saved.predict(X_test_seq)
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 29s 413ms/step

# %%
# put back the residuals
y_pred_tas = X_test_seq[:,window_size,:,:,0] +  y_pred[:,window_size,:,:,0]
y_pred_pr = X_test_seq[:,window_size,:,:,1] +  y_pred[:,window_size,:,:,1]

print(y_pred.shape)
print(y_test_seq[:,window_size,:,:,0].shape)
# Back-transform the predictions for evaluation
y_test_denorm_tas = y_test_seq[:,window_size,:,:,0] * (gmfd_max_tas - gmfd_min_tas) + gmfd_min_tas
y_pred_denorm_tas = y_pred_tas * (cmip6_high_tas_max - cmip6_high_tas_min) + cmip6_high_tas_min

y_test_denorm_pr = y_test_seq[:,window_size,:,:,1] * (gmfd_max_pr - gmfd_min_pr) + gmfd_min_pr
y_pred_denorm_pr = y_pred_pr * (cmip6_high_pr_max - cmip6_high_pr_min) + cmip6_high_pr_min
# back transform from log1p
y_pred_denorm_pr_back = np.expm1(y_pred_denorm_pr)
y_test_denorm_pr_back = np.expm1(y_test_denorm_pr)
y_pred_denorm_pr_back[y_pred_denorm_pr_back < 0] = 0
# Out:
# (1827, 7, 42, 97, 2)
# (1827, 42, 97)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

def evaluate_and_plot(y_test_denorm, y_pred_denorm, title="Predicted vs Actual"):
    """
    Calculates RMSE, MAE, and correlation, and generates a scatter plot
    of predicted vs. actual values.

    Args:
        y_test_denorm (np.ndarray): The actual/observed (denormalized) values.
        y_pred_denorm (np.ndarray): The predicted (denormalized) values.
        title (str, optional): The title of the plot. Defaults to "Predicted vs Actual".
    """

    # Calculate RMSE, MAE, and correlation
    rmse = np.sqrt(mean_squared_error(y_test_denorm.flatten(), y_pred_denorm.flatten()))
    mae = mean_absolute_error(y_test_denorm.flatten(), y_pred_denorm.flatten())
    correlation = np.corrcoef(y_test_denorm.flatten(), y_pred_denorm.flatten())[0,1]

    # Create the plot
    plt.figure(figsize=(8, 8))
    plt.grid(True, linestyle='--', alpha=0.7)  # Add grid
    plt.scatter(y_test_denorm.flatten(), y_pred_denorm.flatten(), alpha=0.5)
    plt.xlabel('Actual Values (GMFD)')
    plt.ylabel('Predicted Values')
    plt.title(f'{title} (Back-transformed)')
    plt.plot([y_test_denorm.min(), y_test_denorm.max()],
            [y_test_denorm.min(), y_test_denorm.max()], 'r--')

    # Add RMSE, MAE, and correlation text to the upper left
    plt.text(0.05, 0.95, f'RMSE: {rmse:.3f}\nMAE: {mae:.3f}\nCorr: {correlation:.3f}',
            transform=plt.gca().transAxes,
            verticalalignment='top',
            bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

    plt.show()

evaluate_and_plot(y_test_denorm_tas, y_pred_denorm_tas, title="Temperature")
evaluate_and_plot(y_test_denorm_pr_back, y_pred_denorm_pr_back, title="Precipitation")

# %%
evaluate_and_plot( gmfd_pr['prcp'].values[index_2009:], cmip6_high_pr.values[index_2009:], title="Precipitation")

# %%
 cmip6_high_pr
# Out:
# <xarray.DataArray 'pr' (time: 23741, lat: 42, lon: 97)> Size: 774MB
# dask.array<mul, shape=(23741, 42, 97), dtype=float64, chunksize=(100, 42, 97), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 336B 41.12 41.38 41.62 41.88 ... 50.88 51.12 51.38
#   * lon      (lon) float64 776B 6.875 7.125 7.375 7.625 ... 30.38 30.62 30.88
#   * time     (time) datetime64[ns] 190kB 1950-01-01 1950-01-02 ... 2014-12-31

# %% [markdown]
# #### Train the on All Data
# Train the model on all the data (no splitting)

# %%
X_all = np.concatenate((X_train_seq, X_val_seq, X_test_seq), axis=0)
y_all = np.concatenate((y_train_seq, y_val_seq, y_test_seq), axis=0)
res_all = np.concatenate((res_train_seq, res_val_seq, res_test_seq), axis=0)

# %%
import tensorflow as tf
from keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint, TerminateOnNaN


# Model setup
input_shape = (7, 42, 97, 3)
patch_size = (7, 7, 7)

model = vit_transformer(
    input_shape=input_shape,
    patch_size=patch_size,
    embed_dim=320,
    num_heads=10,
    transformer_layers=8,
    mlp_dim=512,
    dropout=0.2,
    weight_decay=0.01
)


climate_loss = ClimateDownscalingLoss(
    spatial_weight_temp=0.1,
    gradient_weight_temp=0.05,
    temporal_weight_temp=0.05,
    spatial_weight_precip=0.5,
    gradient_weight_precip=0.05,
    temporal_weight_precip=0.05,
    mse_weight_temp=1.0,
    mse_weight_precip=1.0,
    observation_weight=0.01

)

# Training parameters
epochs = 500
batch_size = 100

# Learning rate schedule using CosineDecayRestarts
initial_learning_rate = 1e-4
lr_schedule = tf.keras.optimizers.schedules.CosineDecayRestarts(
    initial_learning_rate=initial_learning_rate,
    first_decay_steps=50,  # Number of steps in the first cycle
    t_mul=2.0,             # Cycle length multiplier
    m_mul=0.8,             # Multiplier for the max learning rate
    alpha=1e-6             # Minimum learning rate
)

# Optimizer with learning rate schedule
optimizer = AdamW(learning_rate=lr_schedule, weight_decay=1e-5)


# Compile the model
model.compile(
    optimizer=optimizer,
    loss=climate_loss,
    metrics=[
        tf.keras.metrics.MeanAbsoluteError(),
        tf.keras.metrics.RootMeanSquaredError()
    ]
)

# Custom callback to log learning rate
class LRLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f'\nLearning rate for epoch {epoch+1} is {lr}')

# Callbacks for training
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=20,
        restore_best_weights=True,
        min_delta=1e-4
    ),
    ModelCheckpoint(
        filepath='models/vit_transformer_final_model.keras',
        monitor='val_loss',
        save_best_only=True,
        save_weights_only=False,
        mode='min',
        verbose=1
    ),
    TerminateOnNaN(),
    LRLogger()  # Add the learning rate logger
]


# Perform training
history = model.fit(
    X_all, res_all,
    validation_split=0.2,
    epochs=epochs,
    batch_size=batch_size,
    callbacks=callbacks,
    verbose=1,
    shuffle=False  # Sequential data training
)

# Summarize results
print("\nTraining completed.")
best_val_loss = min(history.history['val_loss'])
best_epoch = history.history['val_loss'].index(best_val_loss) + 1
print(f"Best validation loss: {best_val_loss:.6f} at epoch {best_epoch}")
# Out:
# Epoch 1/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 64.7751 - mean_absolute_error: 0.1183 - root_mean_squared_error: 0.1807
# Epoch 1: val_loss improved from inf to 49.41156, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 1 is 5.78885859314545e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 69s 283ms/step - loss: 64.7461 - mean_absolute_error: 0.1182 - root_mean_squared_error: 0.1807 - val_loss: 49.4116 - val_mean_absolute_error: 0.1055 - val_root_mean_squared_error: 0.1718
# Epoch 2/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 45.6792 - mean_absolute_error: 0.1034 - root_mean_squared_error: 0.1685
# Epoch 2: val_loss improved from 49.41156 to 39.39364, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 2 is 5.049271946951058e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 22s 46ms/step - loss: 45.6676 - mean_absolute_error: 0.1034 - root_mean_squared_error: 0.1685 - val_loss: 39.3936 - val_mean_absolute_error: 0.1038 - val_root_mean_squared_error: 0.1713
# Epoch 3/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 36.0620 - mean_absolute_error: 0.1021 - root_mean_squared_error: 0.1681
# Epoch 3: val_loss improved from 39.39364 to 29.06963, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 3 is 2.1595356099692393e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 36.0333 - mean_absolute_error: 0.1021 - root_mean_squared_error: 0.1682 - val_loss: 29.0696 - val_mean_absolute_error: 0.1032 - val_root_mean_squared_error: 0.1712
# Epoch 4/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 28.2782 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1680
# Epoch 4: val_loss improved from 29.06963 to 26.94528, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 4 is 4.094426971799935e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 28.2758 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1680 - val_loss: 26.9453 - val_mean_absolute_error: 0.1032 - val_root_mean_squared_error: 0.1711
# Epoch 5/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 24.8922 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1679
# Epoch 5: val_loss improved from 26.94528 to 19.63098, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 5 is 3.4961611917153625e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 24.8726 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1679 - val_loss: 19.6310 - val_mean_absolute_error: 0.1030 - val_root_mean_squared_error: 0.1710
# Epoch 6/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 18.4197 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1678
# Epoch 6: val_loss improved from 19.63098 to 15.53654, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 6 is 2.1284119742704706e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - loss: 18.4086 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1678 - val_loss: 15.5365 - val_mean_absolute_error: 0.1030 - val_root_mean_squared_error: 0.1709
# Epoch 7/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 14.9726 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1677
# Epoch 7: val_loss improved from 15.53654 to 13.80718, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 7 is 7.179396790893872e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 14.9702 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1677 - val_loss: 13.8072 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1709
# Epoch 8/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 13.6593 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1677
# Epoch 8: val_loss improved from 13.80718 to 13.46502, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 8 is 1.4205785960511026e-07
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 13.6588 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1677 - val_loss: 13.4650 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1708
# Epoch 9/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 12.9516 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1677
# Epoch 9: val_loss improved from 13.46502 to 10.44375, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 9 is 3.196617799686984e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 12.9473 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1677 - val_loss: 10.4438 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1707
# Epoch 10/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.7290 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1676
# Epoch 10: val_loss improved from 10.44375 to 7.82031, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 10 is 2.904907421889182e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 9.7220 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1676 - val_loss: 7.8203 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1706
# Epoch 11/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.3234 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1675
# Epoch 11: val_loss improved from 7.82031 to 6.02318, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 11 is 2.43896460311157e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - loss: 7.3210 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1675 - val_loss: 6.0232 - val_mean_absolute_error: 0.1028 - val_root_mean_squared_error: 0.1705
# Epoch 12/500
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.6956 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1674
# Epoch 12: val_loss improved from 6.02318 to 4.84016, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 12 is 1.8628891577307163e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 5.6909 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1674 - val_loss: 4.8402 - val_mean_absolute_error: 0.1028 - val_root_mean_squared_error: 0.1704
# Epoch 13/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.6301 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1673
# Epoch 13: val_loss improved from 4.84016 to 4.10065, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 13 is 1.2559318599353698e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 4.6291 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1673 - val_loss: 4.1007 - val_mean_absolute_error: 0.1028 - val_root_mean_squared_error: 0.1703
# Epoch 14/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.9768 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1672
# Epoch 14: val_loss improved from 4.10065 to 3.67756, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 14 is 7.015919043804739e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 3.9763 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1672 - val_loss: 3.6776 - val_mean_absolute_error: 0.1028 - val_root_mean_squared_error: 0.1703
# Epoch 15/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.6147 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1672
# Epoch 15: val_loss improved from 3.67756 to 3.47613, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 15 is 2.761299110833226e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 3.6144 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1672 - val_loss: 3.4761 - val_mean_absolute_error: 0.1028 - val_root_mean_squared_error: 0.1703
# Epoch 16/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.4539 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1672
# Epoch 16: val_loss improved from 3.47613 to 3.41587, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 16 is 3.807674197710265e-07
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 3.4538 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1672 - val_loss: 3.4159 - val_mean_absolute_error: 0.1028 - val_root_mean_squared_error: 0.1703
# Epoch 17/500
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.3991 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1672
# Epoch 17: val_loss improved from 3.41587 to 2.94554, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 17 is 2.617406870271199e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 3.3977 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1672 - val_loss: 2.9455 - val_mean_absolute_error: 0.1028 - val_root_mean_squared_error: 0.1702
# Epoch 18/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.7036 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1671
# Epoch 18: val_loss improved from 2.94554 to 2.05888, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 18 is 2.575668788110828e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 2.7025 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1671 - val_loss: 2.0589 - val_mean_absolute_error: 0.1028 - val_root_mean_squared_error: 0.1701
# Epoch 19/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.8879 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1670
# Epoch 19: val_loss improved from 2.05888 to 1.43410, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 19 is 2.4900455808348577e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 1.8871 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1670 - val_loss: 1.4341 - val_mean_absolute_error: 0.1028 - val_root_mean_squared_error: 0.1700
# Epoch 20/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.3146 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1669
# Epoch 20: val_loss improved from 1.43410 to 0.99873, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 20 is 2.363507812162136e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 1.3140 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1669 - val_loss: 0.9987 - val_mean_absolute_error: 0.1028 - val_root_mean_squared_error: 0.1699
# Epoch 21/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9161 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1668
# Epoch 21: val_loss improved from 0.99873 to 0.69842, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 21 is 2.2004455127472254e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.9157 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1668 - val_loss: 0.6984 - val_mean_absolute_error: 0.1028 - val_root_mean_squared_error: 0.1698
# Epoch 22/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6421 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1667
# Epoch 22: val_loss improved from 0.69842 to 0.49297, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 22 is 2.0065158749094096e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 0.6415 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1667 - val_loss: 0.4930 - val_mean_absolute_error: 0.1028 - val_root_mean_squared_error: 0.1697
# Epoch 23/500
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4548 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1666
# Epoch 23: val_loss improved from 0.49297 to 0.35322, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 23 is 1.7884469851628257e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 0.4542 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1666 - val_loss: 0.3532 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1696
# Epoch 24/500
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3273 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1666
# Epoch 24: val_loss improved from 0.35322 to 0.25847, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 24 is 1.5538044037416677e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - loss: 0.3269 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1666 - val_loss: 0.2585 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1695
# Epoch 25/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2407 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1665
# Epoch 25: val_loss improved from 0.25847 to 0.19431, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 25 is 1.3107286892800005e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 0.2406 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1665 - val_loss: 0.1943 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1695
# Epoch 26/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1823 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1665
# Epoch 26: val_loss improved from 0.19431 to 0.15090, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 26 is 1.0676529748183336e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 0.1822 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1665 - val_loss: 0.1509 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1694
# Epoch 27/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1428 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1664
# Epoch 27: val_loss improved from 0.15090 to 0.12160, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 27 is 8.330103933971755e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 0.1427 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1664 - val_loss: 0.1216 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1694
# Epoch 28/500
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1162 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1664
# Epoch 28: val_loss improved from 0.12160 to 0.10198, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 28 is 6.149415036505914e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 0.1161 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1664 - val_loss: 0.1020 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1693
# Epoch 29/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0984 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1664
# Epoch 29: val_loss improved from 0.10198 to 0.08912, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 29 is 4.210118658127759e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 0.0983 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1664 - val_loss: 0.0891 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1693
# Epoch 30/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0868 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1664
# Epoch 30: val_loss improved from 0.08912 to 0.08108, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 30 is 2.5794956639786497e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 0.0868 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1664 - val_loss: 0.0811 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1693
# Epoch 31/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0797 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663
# Epoch 31: val_loss improved from 0.08108 to 0.07652, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 31 is 1.3141179772514343e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0797 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663 - val_loss: 0.0765 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1693
# Epoch 32/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0758 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663
# Epoch 32: val_loss improved from 0.07652 to 0.07443, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 32 is 4.5788590449172533e-07
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0758 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663 - val_loss: 0.0744 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1693
# Epoch 33/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0742 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663
# Epoch 33: val_loss improved from 0.07443 to 0.07388, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 33 is 4.0505082888021875e-08
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0742 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663 - val_loss: 0.0739 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1693
# Epoch 34/500
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0719 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663
# Epoch 34: val_loss improved from 0.07388 to 0.04646, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 34 is 2.095631671408027e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 0.0718 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663 - val_loss: 0.0465 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1692
# Epoch 35/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0387 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663
# Epoch 35: val_loss improved from 0.04646 to 0.02145, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 35 is 2.085810662310083e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.0386 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663 - val_loss: 0.0214 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1692
# Epoch 36/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0182 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1662
# Epoch 36: val_loss improved from 0.02145 to 0.01112, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 36 is 2.066973828925556e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0182 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1662 - val_loss: 0.0111 - val_mean_absolute_error: 0.1030 - val_root_mean_squared_error: 0.1691
# Epoch 37/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0098 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1661
# Epoch 37: val_loss improved from 0.01112 to 0.00706, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 37 is 2.039284905703109e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0098 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1661 - val_loss: 0.0071 - val_mean_absolute_error: 0.1030 - val_root_mean_squared_error: 0.1690
# Epoch 38/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0065 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1661
# Epoch 38: val_loss improved from 0.00706 to 0.00555, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 38 is 2.0029845716616263e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0065 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1661 - val_loss: 0.0056 - val_mean_absolute_error: 0.1030 - val_root_mean_squared_error: 0.1689
# Epoch 39/500
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0054 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1660
# Epoch 39: val_loss improved from 0.00555 to 0.00503, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 39 is 1.9583883583482224e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0054 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1660 - val_loss: 0.0050 - val_mean_absolute_error: 0.1030 - val_root_mean_squared_error: 0.1689
# Epoch 40/500
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0049 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1660
# Epoch 40: val_loss improved from 0.00503 to 0.00486, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 40 is 1.9058839071594228e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0049 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1660 - val_loss: 0.0049 - val_mean_absolute_error: 0.1030 - val_root_mean_squared_error: 0.1688
# Epoch 41/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0048 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1659
# Epoch 41: val_loss improved from 0.00486 to 0.00481, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 41 is 1.8459275998655727e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.0048 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1659 - val_loss: 0.0048 - val_mean_absolute_error: 0.1031 - val_root_mean_squared_error: 0.1688
# Epoch 42/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1659
# Epoch 42: val_loss improved from 0.00481 to 0.00479, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 42 is 1.7790405916267898e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0048 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1659 - val_loss: 0.0048 - val_mean_absolute_error: 0.1031 - val_root_mean_squared_error: 0.1687
# Epoch 43/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1659
# Epoch 43: val_loss improved from 0.00479 to 0.00479, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 43 is 1.7058042809824704e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0048 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1659 - val_loss: 0.0048 - val_mean_absolute_error: 0.1031 - val_root_mean_squared_error: 0.1687
# Epoch 44/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1658
# Epoch 44: val_loss improved from 0.00479 to 0.00479, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 44 is 1.6268552561903484e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1658 - val_loss: 0.0048 - val_mean_absolute_error: 0.1031 - val_root_mean_squared_error: 0.1686
# Epoch 45/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1658
# Epoch 45: val_loss improved from 0.00479 to 0.00479, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 45 is 1.5428797618427532e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1658 - val_loss: 0.0048 - val_mean_absolute_error: 0.1031 - val_root_mean_squared_error: 0.1686
# Epoch 46/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1658
# Epoch 46: val_loss improved from 0.00479 to 0.00479, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 46 is 1.4546077338576547e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1658 - val_loss: 0.0048 - val_mean_absolute_error: 0.1031 - val_root_mean_squared_error: 0.1685
# Epoch 47/500
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1657
# Epoch 47: val_loss improved from 0.00479 to 0.00479, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 47 is 1.3628064546938096e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1657 - val_loss: 0.0048 - val_mean_absolute_error: 0.1032 - val_root_mean_squared_error: 0.1685
# Epoch 48/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657
# Epoch 48: val_loss improved from 0.00479 to 0.00479, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 48 is 1.268273883940474e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657 - val_loss: 0.0048 - val_mean_absolute_error: 0.1032 - val_root_mean_squared_error: 0.1685
# Epoch 49/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657
# Epoch 49: val_loss improved from 0.00479 to 0.00479, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 49 is 1.1718317222538561e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657 - val_loss: 0.0048 - val_mean_absolute_error: 0.1032 - val_root_mean_squared_error: 0.1685
# Epoch 50/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657
# Epoch 50: val_loss improved from 0.00479 to 0.00479, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 50 is 1.0743182689302985e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657 - val_loss: 0.0048 - val_mean_absolute_error: 0.1032 - val_root_mean_squared_error: 0.1684
# Epoch 51/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1656
# Epoch 51: val_loss improved from 0.00479 to 0.00479, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 51 is 9.765811351999472e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657 - val_loss: 0.0048 - val_mean_absolute_error: 0.1032 - val_root_mean_squared_error: 0.1684
# Epoch 52/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1656
# Epoch 52: val_loss improved from 0.00479 to 0.00479, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 52 is 8.794698765787714e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1656 - val_loss: 0.0048 - val_mean_absolute_error: 0.1032 - val_root_mean_squared_error: 0.1684
# Epoch 53/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1656
# Epoch 53: val_loss improved from 0.00479 to 0.00479, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 53 is 7.838286083203619e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1656 - val_loss: 0.0048 - val_mean_absolute_error: 0.1032 - val_root_mean_squared_error: 0.1684
# Epoch 54/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 54: val_loss improved from 0.00479 to 0.00479, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 54 is 6.904886681558561e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0048 - val_mean_absolute_error: 0.1032 - val_root_mean_squared_error: 0.1684
# Epoch 55/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 55: val_loss improved from 0.00479 to 0.00479, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 55 is 6.002613900992587e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0048 - val_mean_absolute_error: 0.1032 - val_root_mean_squared_error: 0.1684
# Epoch 56/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 56: val_loss improved from 0.00479 to 0.00479, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 56 is 5.13931052130066e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0048 - val_mean_absolute_error: 0.1032 - val_root_mean_squared_error: 0.1683
# Epoch 57/500
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 57: val_loss improved from 0.00479 to 0.00478, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 57 is 4.322480590536767e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0048 - val_mean_absolute_error: 0.1032 - val_root_mean_squared_error: 0.1683
# Epoch 58/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 58: val_loss improved from 0.00478 to 0.00478, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 58 is 3.559224197958714e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0048 - val_mean_absolute_error: 0.1032 - val_root_mean_squared_error: 0.1683
# Epoch 59/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 59: val_loss improved from 0.00478 to 0.00478, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 59 is 2.856175758283454e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0048 - val_mean_absolute_error: 0.1033 - val_root_mean_squared_error: 0.1683
# Epoch 60/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 60: val_loss improved from 0.00478 to 0.00478, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 60 is 2.2194463437014754e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0048 - val_mean_absolute_error: 0.1033 - val_root_mean_squared_error: 0.1683
#
# Training completed.
# Best validation loss: 0.004785 at epoch 60

# %% [markdown]
# ## Make prediction

# %%
from keras.models import load_model
model_saved = load_model('models/vit_transformer_final_model.keras')

# %% [markdown]
# ### Historical

# %%
# Load the CMIP6 raw data (predictor variables)
cmip6_historical = '/data/cristi/a/cristi/downscaled_data/cmip6/raw/zarr/RO_CMIP6_raw/CNRM-ESM2-1/historical/r1i1p1f2/tas/tas_day_CNRM-ESM2-1_historical_r1i1p1f2_gr_1950_2014_rou.zarr'
cmip6_historical = xr.open_zarr(cmip6_historical)
cmip6_historical_high_res = cmip6_historical.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
# Get the mean and std from the training set for denormalization
cmip6_historical_tas_min = cmip6_historical_high_res['tas'].min().values
cmip6_historical_tas_max = cmip6_historical_high_res['tas'].max().values
cmip6_historical_norm = normalize(cmip6_historical_high_res['tas'])
cmip6_historical_norm = cmip6_historical_norm.values
cmip6_historical_norm_reshaped = cmip6_historical_norm[..., np.newaxis]


cmip6_historical_pr = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/historical/r1i1p1f2/pr/pr_day_CNRM-ESM2-1_historical_r1i1p1f2_gr_1950_2014_rou.zarr'
cmip6_historical_pr = xr.open_zarr(cmip6_historical_pr)
cmip6_historical_pr = cmip6_historical_pr * 86400
cmip6_historical_pr_high_res = cmip6_historical_pr.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_historical_pr_high_res['pr'] = xr.where(cmip6_historical_pr_high_res['pr'] < 0, 0, cmip6_historical_pr_high_res['pr'])

cmip6_historical_pr_high_res_log1p = cmip6_historical_pr_high_res.copy()  # Make a copy to avoid modifying the original dataset
cmip6_historical_pr_high_res_log1p = xr.apply_ufunc(np.log1p, cmip6_historical_pr_high_res_log1p  ,dask="parallelized", output_dtypes=[float])
cmip6_historical_pr_min = cmip6_historical_pr_high_res_log1p['pr'].min().values
cmip6_historical_pr_max = cmip6_historical_pr_high_res_log1p['pr'].max().values

cmip6_historical_pr_norm_log1p = normalize(cmip6_historical_pr_high_res_log1p ['pr'])
cmip6_historical_pr_norm_log1p = cmip6_historical_pr_norm_log1p.values
cmip6_historical_pr_norm_log1p_reshaped = cmip6_historical_pr_norm_log1p[..., np.newaxis]

cmip6_historical_psl = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/historical/r1i1p1f2/psl/psl_day_CNRM-ESM2-1_historical_r1i1p1f2_gr_1950_2014_rou.zarr'
cmip6_historical_psl = xr.open_zarr(cmip6_historical_psl)
cmip6_historical_psl_high_res = cmip6_historical_psl.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_historical_psl_norm = normalize(cmip6_historical_psl_high_res['psl'])
cmip6_historical_psl_norm = cmip6_historical_psl_norm.values
cmip6_historical_psl_norm_reshaped = cmip6_historical_psl_norm[..., np.newaxis]


# Concatenate the reshaped arrays along the last axis
cmip6_scen_combined = np.concatenate((cmip6_historical_norm_reshaped, cmip6_historical_pr_norm_log1p_reshaped, cmip6_historical_psl_norm_reshaped), axis=-1)
# Predict downscaled high-resolution data
X_scen = create_temporal_sequences_centered(cmip6_scen_combined, window_size) 
predicted_high_res = model_saved.predict(X_scen)

# temperature
predicted_high_res_tas = cmip6_historical_norm_reshaped +  predicted_high_res[:,window_size,:,:,:1]
# Back-transform the predictions and actual values
predicted_high_res_denorm = predicted_high_res_tas * (cmip6_historical_tas_max- cmip6_historical_tas_min) + cmip6_historical_tas_min
# Reshape the predictions to match the original GMFD resolution
predicted_high_res_final = predicted_high_res_denorm.reshape(cmip6_historical_high_res['tas'].shape)
# Save the predictions to a NetCDF file
predicted_tas = xr.DataArray(predicted_high_res_final, dims=cmip6_historical_high_res['tas'].dims, coords=cmip6_historical_high_res['tas'].coords, name='tas_downscaled')
predicted_tas.to_netcdf('/data/keeling/a/ad87/downscale/ncs/vit/predicted_high_res_tas_vit.nc')
# #### Results saved to NetCDF format
print("Downscaled high-resolution predictions saved to NetCDF format.")

# precipitation
predicted_high_res_pr = cmip6_historical_pr_norm_log1p_reshaped  +  predicted_high_res[:,window_size,:,:,1:2]
# Back-transform the predictions and actual values
predicted_high_res_denorm = predicted_high_res_pr * (cmip6_historical_pr_max - cmip6_historical_pr_min) + cmip6_historical_pr_min
predicted_high_res_denorm_back = np.expm1(predicted_high_res_denorm)
predicted_high_res_denorm_back[predicted_high_res_denorm_back < 0] = 0 # Replace negative values with 0

# Reshape the predictions to match the original GMFD resolution
predicted_high_res_final = predicted_high_res_denorm_back.reshape(cmip6_historical_high_res['tas'].shape)
# Save the predictions to a NetCDF file
predicted_pr = xr.DataArray(predicted_high_res_final, dims=cmip6_historical_high_res['tas'].dims, coords=cmip6_historical_high_res['tas'].coords, name='pr_downscaled')
predicted_pr.to_netcdf('/data/keeling/a/ad87/downscale/ncs/vit/predicted_high_res_pr_vit.nc')
# #### Results saved to NetCDF format
print("Downscaled high-resolution predictions saved to NetCDF format.")
# Out:
# 742/742 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# Downscaled high-resolution predictions saved to NetCDF format.
# Downscaled high-resolution predictions saved to NetCDF format.

# %% [markdown]
# ### Scenario data

# %% [markdown]
# #### SSP 126

# %%
# Load the CMIP6 raw data (predictor variables)
cmip6_ssp126 = '/data/cristi/a/cristi/downscaled_data/cmip6/raw/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp126/r1i1p1f2/tas/tas_day_CNRM-ESM2-1_ssp126_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_ssp126 = xr.open_zarr(cmip6_ssp126)
cmip6_sp126_high_res = cmip6_ssp126.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
# Get the mean and std from the training set for denormalization
cmip6_sp126_tas_min = cmip6_sp126_high_res['tas'].min().values
cmip6_sp126_tas_max = cmip6_sp126_high_res['tas'].max().values
cmip6_sp126_norm = normalize(cmip6_sp126_high_res['tas'])
cmip6_sp126_norm = cmip6_sp126_norm.values
cmip6_sp126_norm_reshaped = cmip6_sp126_norm[..., np.newaxis]


cmip6_sp126_pr = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp126/r1i1p1f2/pr/pr_day_CNRM-ESM2-1_ssp126_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_sp126_pr = xr.open_zarr(cmip6_sp126_pr)
cmip6_sp126_pr = cmip6_sp126_pr * 86400
cmip6_sp126_pr_high_res = cmip6_sp126_pr.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_sp126_pr_high_res['pr'] = xr.where(cmip6_sp126_pr_high_res['pr'] < 0, 0, cmip6_sp126_pr_high_res['pr'])

cmip6_sp126_pr_high_res_log1p = cmip6_sp126_pr_high_res.copy()  # Make a copy to avoid modifying the original dataset
cmip6_sp126_pr_high_res_log1p = xr.apply_ufunc(np.log1p, cmip6_sp126_pr_high_res_log1p  ,dask="parallelized", output_dtypes=[float])
cmip6_sp126_pr_min = cmip6_sp126_pr_high_res_log1p['pr'].min().values
cmip6_sp126_pr_max = cmip6_sp126_pr_high_res_log1p['pr'].max().values

cmip6_sp126_pr_norm_log1p = normalize(cmip6_sp126_pr_high_res_log1p ['pr'])
cmip6_sp126_pr_norm_log1p = cmip6_sp126_pr_norm_log1p.values
cmip6_sp126_pr_norm_log1p_reshaped = cmip6_sp126_pr_norm_log1p[..., np.newaxis]

cmip6_sp126_psl = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp126/r1i1p1f2/psl/psl_day_CNRM-ESM2-1_ssp126_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_sp126_psl = xr.open_zarr(cmip6_sp126_psl)
cmip6_sp126_psl_high_res = cmip6_sp126_psl.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_sp126_psl_norm = normalize(cmip6_sp126_psl_high_res['psl'])
cmip6_sp126_psl_norm = cmip6_sp126_psl_norm.values
cmip6_sp126_psl_norm_reshaped = cmip6_sp126_psl_norm[..., np.newaxis]


# Concatenate the reshaped arrays along the last axis
cmip6_scen_combined = np.concatenate((cmip6_sp126_norm_reshaped, cmip6_sp126_pr_norm_log1p_reshaped, cmip6_sp126_psl_norm_reshaped), axis=-1)
# Predict downscaled high-resolution data
X_scen = create_temporal_sequences_centered(cmip6_scen_combined, window_size) 
predicted_high_res = model_saved.predict(X_scen)

# temperature
predicted_high_res_tas = cmip6_sp126_norm_reshaped +  predicted_high_res[:,window_size,:,:,:1]
# Back-transform the predictions and actual values
predicted_high_res_denorm = predicted_high_res_tas * (cmip6_sp126_tas_max- cmip6_sp126_tas_min) + cmip6_sp126_tas_min
# Reshape the predictions to match the original GMFD resolution
predicted_high_res_final = predicted_high_res_denorm.reshape(cmip6_sp126_high_res['tas'].shape)
# Save the predictions to a NetCDF file
predicted_tas = xr.DataArray(predicted_high_res_final, dims=cmip6_sp126_high_res['tas'].dims, coords=cmip6_sp126_high_res['tas'].coords, name='tas_downscaled')
predicted_tas.to_netcdf('/data/keeling/a/ad87/downscale/ncs/vit/predicted_high_res_tas_vit_ssp126.nc')
# #### Results saved to NetCDF format
print("Downscaled high-resolution predictions saved to NetCDF format.")

# precipitation
predicted_high_res_pr = cmip6_sp126_pr_norm_log1p_reshaped  +  predicted_high_res[:,window_size,:,:,1:2]
# Back-transform the predictions and actual values
predicted_high_res_denorm = predicted_high_res_pr * (cmip6_sp126_pr_max - cmip6_sp126_pr_min) + cmip6_sp126_pr_min
predicted_high_res_denorm_back = np.expm1(predicted_high_res_denorm)
predicted_high_res_denorm_back[predicted_high_res_denorm_back < 0] = 0 # Replace negative values with 0

# Reshape the predictions to match the original GMFD resolution
predicted_high_res_final = predicted_high_res_denorm_back.reshape(cmip6_sp126_high_res['tas'].shape)
# Save the predictions to a NetCDF file
predicted_pr = xr.DataArray(predicted_high_res_final, dims=cmip6_sp126_high_res['tas'].dims, coords=cmip6_sp126_high_res['tas'].coords, name='pr_downscaled')
predicted_pr.to_netcdf('/data/keeling/a/ad87/downscale/ncs/vit/predicted_high_res_pr_vit_ssp126.nc')
# #### Results saved to NetCDF format
print("Downscaled high-resolution predictions saved to NetCDF format.")
# Out:
# 982/982 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step
# Downscaled high-resolution predictions saved to NetCDF format.
# Downscaled high-resolution predictions saved to NetCDF format.

# %%
predicted_high_res_denorm[predicted_high_res_denorm < 0] = 0
predicted_high_res_denorm.min()
# Out:
# 0.0

# %%
predicted_pr.isel(time=5000).plot()

# %%
gmfd_pr['prcp'].isel(time=5000).plot() # Use .compute() if using Dask

# %%
cmip6_sp126_pr['pr'].isel(time=5000).plot()  # Use .compute() if using Dask

# %% [markdown]
# #### SSP 245

# %%
# Load the CMIP6 raw data (predictor variables)
cmip6_ssp245 = '/data/cristi/a/cristi/downscaled_data/cmip6/raw/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp245/r1i1p1f2/tas/tas_day_CNRM-ESM2-1_ssp245_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_ssp245 = xr.open_zarr(cmip6_ssp245)
cmip6_sp245_high_res = cmip6_ssp245.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
# Get the mean and std from the training set for denormalization
cmip6_sp245_tas_min = cmip6_sp245_high_res['tas'].min().values
cmip6_sp245_tas_max = cmip6_sp245_high_res['tas'].max().values
cmip6_sp245_norm = normalize(cmip6_sp245_high_res['tas'])
cmip6_sp245_norm = cmip6_sp245_norm.values
cmip6_sp245_norm_reshaped = cmip6_sp245_norm[..., np.newaxis]


cmip6_sp245_pr = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp245/r1i1p1f2/pr/pr_day_CNRM-ESM2-1_ssp245_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_sp245_pr = xr.open_zarr(cmip6_sp245_pr)
cmip6_sp245_pr = cmip6_sp245_pr * 86400
cmip6_sp245_pr_high_res = cmip6_sp245_pr.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_sp245_pr_high_res['pr'] = xr.where(cmip6_sp245_pr_high_res['pr'] < 0, 0, cmip6_sp245_pr_high_res['pr'])

cmip6_sp245_pr_high_res_log1p = cmip6_sp245_pr_high_res.copy()  # Make a copy to avoid modifying the original dataset
cmip6_sp245_pr_high_res_log1p = xr.apply_ufunc(np.log1p, cmip6_sp245_pr_high_res_log1p  ,dask="parallelized", output_dtypes=[float])
cmip6_sp245_pr_min = cmip6_sp245_pr_high_res_log1p['pr'].min().values
cmip6_sp245_pr_max = cmip6_sp245_pr_high_res_log1p['pr'].max().values

cmip6_sp245_pr_norm_log1p = normalize(cmip6_sp245_pr_high_res_log1p ['pr'])
cmip6_sp245_pr_norm_log1p = cmip6_sp245_pr_norm_log1p.values
cmip6_sp245_pr_norm_log1p_reshaped = cmip6_sp245_pr_norm_log1p[..., np.newaxis]

cmip6_sp245_psl = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp245/r1i1p1f2/psl/psl_day_CNRM-ESM2-1_ssp245_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_sp245_psl = xr.open_zarr(cmip6_sp245_psl)
cmip6_sp245_psl_high_res = cmip6_sp245_psl.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_sp245_psl_norm = normalize(cmip6_sp245_psl_high_res['psl'])
cmip6_sp245_psl_norm = cmip6_sp245_psl_norm.values
cmip6_sp245_psl_norm_reshaped = cmip6_sp245_psl_norm[..., np.newaxis]


# Concatenate the reshaped arrays along the last axis
cmip6_scen_combined = np.concatenate((cmip6_sp245_norm_reshaped, cmip6_sp245_pr_norm_log1p_reshaped, cmip6_sp245_psl_norm_reshaped), axis=-1)
# Predict downscaled high-resolution data
X_scen = create_temporal_sequences_centered(cmip6_scen_combined, window_size) 
predicted_high_res = model_saved.predict(X_scen)

# temperature
predicted_high_res_tas = cmip6_sp245_norm_reshaped +  predicted_high_res[:,window_size,:,:,:1]
# Back-transform the predictions and actual values
predicted_high_res_denorm = predicted_high_res_tas * (cmip6_sp245_tas_max- cmip6_sp245_tas_min) + cmip6_sp245_tas_min
# Reshape the predictions to match the original GMFD resolution
predicted_high_res_final = predicted_high_res_denorm.reshape(cmip6_sp245_high_res['tas'].shape)
# Save the predictions to a NetCDF file
predicted_tas = xr.DataArray(predicted_high_res_final, dims=cmip6_sp245_high_res['tas'].dims, coords=cmip6_sp245_high_res['tas'].coords, name='tas_downscaled')
predicted_tas.to_netcdf('/data/keeling/a/ad87/downscale/ncs/vit/predicted_high_res_tas_vit_ssp245.nc')
# #### Results saved to NetCDF format
print("Downscaled high-resolution predictions saved to NetCDF format.")

# precipitation
predicted_high_res_pr = cmip6_sp245_pr_norm_log1p_reshaped  +  predicted_high_res[:,window_size,:,:,1:2]
# Back-transform the predictions and actual values
predicted_high_res_denorm = predicted_high_res_pr * (cmip6_sp245_pr_max - cmip6_sp245_pr_min) + cmip6_sp245_pr_min
predicted_high_res_denorm_back = np.expm1(predicted_high_res_denorm)
predicted_high_res_denorm_back[predicted_high_res_denorm_back < 0] = 0 # Replace negative values with 0

# Reshape the predictions to match the original GMFD resolution
predicted_high_res_final = predicted_high_res_denorm_back.reshape(cmip6_sp245_high_res['tas'].shape)
# Save the predictions to a NetCDF file
predicted_pr = xr.DataArray(predicted_high_res_final, dims=cmip6_sp245_high_res['tas'].dims, coords=cmip6_sp245_high_res['tas'].coords, name='pr_downscaled')
predicted_pr.to_netcdf('/data/keeling/a/ad87/downscale/ncs/vit/predicted_high_res_pr_vit_ssp245.nc')
# #### Results saved to NetCDF format
print("Downscaled high-resolution predictions saved to NetCDF format.")
# Out:
# 982/982 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step
# Downscaled high-resolution predictions saved to NetCDF format.
# Downscaled high-resolution predictions saved to NetCDF format.

# %% [markdown]
# #### SSP 585

# %%
# Load the CMIP6 raw data (predictor variables)
cmip6_ssp585 = '/data/cristi/a/cristi/downscaled_data/cmip6/raw/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp585/r1i1p1f2/tas/tas_day_CNRM-ESM2-1_ssp585_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_ssp585 = xr.open_zarr(cmip6_ssp585)
cmip6_sp585_high_res = cmip6_ssp585.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
# Get the mean and std from the training set for denormalization
cmip6_sp585_tas_min = cmip6_sp585_high_res['tas'].min().values
cmip6_sp585_tas_max = cmip6_sp585_high_res['tas'].max().values
cmip6_sp585_norm = normalize(cmip6_sp585_high_res['tas'])
cmip6_sp585_norm = cmip6_sp585_norm.values
cmip6_sp585_norm_reshaped = cmip6_sp585_norm[..., np.newaxis]


cmip6_sp585_pr = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp585/r1i1p1f2/pr/pr_day_CNRM-ESM2-1_ssp585_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_sp585_pr = xr.open_zarr(cmip6_sp585_pr)
cmip6_sp585_pr = cmip6_sp585_pr * 86400
cmip6_sp585_pr_high_res = cmip6_sp585_pr.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_sp585_pr_high_res['pr'] = xr.where(cmip6_sp585_pr_high_res['pr'] < 0, 0, cmip6_sp585_pr_high_res['pr'])

cmip6_sp585_pr_high_res_log1p = cmip6_sp585_pr_high_res.copy()  # Make a copy to avoid modifying the original dataset
cmip6_sp585_pr_high_res_log1p = xr.apply_ufunc(np.log1p, cmip6_sp585_pr_high_res_log1p  ,dask="parallelized", output_dtypes=[float])
cmip6_sp585_pr_min = cmip6_sp585_pr_high_res_log1p['pr'].min().values
cmip6_sp585_pr_max = cmip6_sp585_pr_high_res_log1p['pr'].max().values

cmip6_sp585_pr_norm_log1p = normalize(cmip6_sp585_pr_high_res_log1p ['pr'])
cmip6_sp585_pr_norm_log1p = cmip6_sp585_pr_norm_log1p.values
cmip6_sp585_pr_norm_log1p_reshaped = cmip6_sp585_pr_norm_log1p[..., np.newaxis]

cmip6_sp585_psl = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp585/r1i1p1f2/psl/psl_day_CNRM-ESM2-1_ssp585_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_sp585_psl = xr.open_zarr(cmip6_sp585_psl)
cmip6_sp585_psl_high_res = cmip6_sp585_psl.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_sp585_psl_norm = normalize(cmip6_sp585_psl_high_res['psl'])
cmip6_sp585_psl_norm = cmip6_sp585_psl_norm.values
cmip6_sp585_psl_norm_reshaped = cmip6_sp585_psl_norm[..., np.newaxis]


# Concatenate the reshaped arrays along the last axis
cmip6_scen_combined = np.concatenate((cmip6_sp585_norm_reshaped, cmip6_sp585_pr_norm_log1p_reshaped, cmip6_sp585_psl_norm_reshaped), axis=-1)
# Predict downscaled high-resolution data
X_scen = create_temporal_sequences_centered(cmip6_scen_combined, window_size) 
predicted_high_res = model_saved.predict(X_scen)

# temperature
predicted_high_res_tas = cmip6_sp585_norm_reshaped +  predicted_high_res[:,window_size,:,:,:1]
# Back-transform the predictions and actual values
predicted_high_res_denorm = predicted_high_res_tas * (cmip6_sp585_tas_max- cmip6_sp585_tas_min) + cmip6_sp585_tas_min
# Reshape the predictions to match the original GMFD resolution
predicted_high_res_final = predicted_high_res_denorm.reshape(cmip6_sp585_high_res['tas'].shape)
# Save the predictions to a NetCDF file
predicted_tas = xr.DataArray(predicted_high_res_final, dims=cmip6_sp585_high_res['tas'].dims, coords=cmip6_sp585_high_res['tas'].coords, name='tas_downscaled')
predicted_tas.to_netcdf('/data/keeling/a/ad87/downscale/ncs/vit/predicted_high_res_tas_vit_ssp585.nc')
# #### Results saved to NetCDF format
print("Downscaled high-resolution predictions saved to NetCDF format.")

# precipitation
predicted_high_res_pr = cmip6_sp585_pr_norm_log1p_reshaped  +  predicted_high_res[:,window_size,:,:,1:2]
# Back-transform the predictions and actual values
predicted_high_res_denorm = predicted_high_res_pr * (cmip6_sp585_pr_max - cmip6_sp585_pr_min) + cmip6_sp585_pr_min
predicted_high_res_denorm_back = np.expm1(predicted_high_res_denorm)
predicted_high_res_denorm_back[predicted_high_res_denorm_back < 0] = 0 # Replace negative values with 0

# Reshape the predictions to match the original GMFD resolution
predicted_high_res_final = predicted_high_res_denorm_back.reshape(cmip6_sp585_high_res['tas'].shape)
# Save the predictions to a NetCDF file
predicted_pr = xr.DataArray(predicted_high_res_final, dims=cmip6_sp585_high_res['tas'].dims, coords=cmip6_sp585_high_res['tas'].coords, name='pr_downscaled')
predicted_pr.to_netcdf('/data/keeling/a/ad87/downscale/ncs/vit/predicted_high_res_pr_vit_ssp585.nc')
# #### Results saved to NetCDF format
print("Downscaled high-resolution predictions saved to NetCDF format.")
# Out:
# 982/982 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step
# Downscaled high-resolution predictions saved to NetCDF format.
# Downscaled high-resolution predictions saved to NetCDF format.
