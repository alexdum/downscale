# %%
import os
os.environ["KERAS_BACKEND"] = "jax"
import keras
from keras import layers
import numpy as np
import xarray as xr
import zarr
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import random
import jax
import tensorflow as tf
from tqdm import tqdm
import jax.numpy as jnp
from jax import grad, jit, vmap
from utils.clim_loss_vit import custom_loss
#from utils.clim_loss import ClimateDownscalingLoss

# Set seed for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
jax.config.update('jax_enable_x64', True)
jax.random.PRNGKey(SEED)


# Set the working directory
os.chdir('/data/keeling/a/ad87/downscale')
# Out:
# 2025-03-10 09:40:25.497605: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741617625.512589 1727106 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741617625.516991 1727106 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ### Data Handling: Load and Resample Data
# We will load the CMIP6 data and the GMFD observational data. We’ll resample the GMFD data to the CMIP6 resolution (e.g., ~100 km) to use as the target during training.

# %%
# Load the CMIP6 raw data (predictor variables)
cmip6_tas_path = '/data/cristi/a/cristi/downscaled_data/cmip6/raw/zarr/RO_CMIP6_raw/CNRM-ESM2-1/historical/r1i1p1f2/tas/tas_day_CNRM-ESM2-1_historical_r1i1p1f2_gr_1950_2014_rou.zarr'
cmip6_tas = xr.open_zarr(cmip6_tas_path)

cmip6_pr_path = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/historical/r1i1p1f2/pr/pr_day_CNRM-ESM2-1_historical_r1i1p1f2_gr_1950_2014_rou.zarr'
cmip6_pr = xr.open_zarr(cmip6_pr_path)
cmip6_lat = cmip6_pr.lat
cmip6_lon = cmip6_pr.lon

cmip6_psl_path = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/historical/r1i1p1f2/psl/psl_day_CNRM-ESM2-1_historical_r1i1p1f2_gr_1950_2014_rou.zarr'
cmip6_psl = xr.open_zarr(cmip6_psl_path)

# Load the GMFD reference observational data (target variable)
gmfd_data_path = '/data/keeling/a/cristi/a/downscaled_data/gmfd/ncs/ro'
gmfd_tas_files = [f'{gmfd_data_path}/tas_daily_ro_{year}.nc' for year in range(1950, 2015)]
gmfd_tas = xr.open_mfdataset(gmfd_tas_files, combine='by_coords')
gmfd_pr_files = [f'{gmfd_data_path}/prcp_daily_ro_{year}.nc' for year in range(1950, 2015)]
gmfd_pr = xr.open_mfdataset(gmfd_pr_files, combine='by_coords')
gmfd_pr['prcp'] = gmfd_pr['prcp'] * 86400

# Resample  CMIP6 to GMFD resolution (~25 km)
target_lat = gmfd_tas.lat
target_lon = gmfd_tas.lon
cmip6_high_tas = cmip6_tas['tas'].interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_high_pr = cmip6_pr['pr'].interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_high_pr = cmip6_high_pr.where(cmip6_high_pr > 0, 0)  # Set negative values to zero
cmip6_high_pr = cmip6_high_pr * 86400
cmip6_high_psl = cmip6_psl['psl'].interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})

cmip6_high_tas['time'] = cmip6_high_tas['time'].dt.floor('D')
cmip6_high_pr['time'] = cmip6_high_pr['time'].dt.floor('D')

# %% [markdown]
# #### Load elevation

# %%
elev = xr.open_dataset('grids/elevation_0.25deg.nc')
elev_sub = elev.sel(latitude=slice(40.99986, 51.49986), longitude=slice( 6.69986, 30.99986 ))
elev_sub['elev'] = elev_sub['elev'].fillna(0) # convert NA to 0
elev_sub = elev_sub.rename({"latitude": "lat"})
elev_sub = elev_sub.rename({"longitude": "lon"})
# Rename the dimension and coordinate


elev_cmip6 = elev_sub.interp(lat=cmip6_lat, lon=cmip6_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
elev_cmip6['elev'] = elev_cmip6['elev'].clip(min=0)
cmip6_high_elev = elev_cmip6.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})

# Set cmip6_high_elev to 0 where cmip6_high_elev < 0 and elev_sub == 0
cmip6_high_elev = xr.where((cmip6_high_elev < 0) & (elev_sub['elev'] == 0), 0, cmip6_high_elev)
cmip6_high_elev['elev'] = cmip6_high_elev['elev'].clip(min=0)
#elev_dif = elev_sub - cmip6_high_elev
elev_dif = elev_sub 


# Check the new shape of 'elev'
elev_dif = elev_dif.squeeze(dim="z")

# elev_cmip6['elev'].plot(cmap = 'terrain')
# elev_dif_norm.plot(cmap = 'terrain')
# elev_dif['elev'].plot(cmap = 'terrain')

# %% [markdown]
# #### Transform (pr) and normalize

# %%
# Apply the log1p transformation to the 'prcp' variable
cmip6_high_pr_log1p = cmip6_high_pr.copy()  # Make a copy to avoid modifying the original dataset
# Apply the log1p transformation to the precipitation data
cmip6_high_pr_log1p = xr.apply_ufunc(
    np.log1p,                 # The function to apply (log1p)
   cmip6_high_pr,               # The data variable to transform
    dask="parallelized",      # Enable parallel computations with Dask
    output_dtypes=[float]     # Specify output data type
)

# Apply the log1p transformation to the 'prcp' variable
gmfd_pr_log1p = gmfd_pr.copy()  # Make a copy to avoid modifying the original dataset
# Apply the log1p transformation to the precipitation data
gmfd_pr_log1p['prcp'] = xr.apply_ufunc(
    np.log1p,                 # The function to apply (log1p)
    gmfd_pr['prcp'],               # The data variable to transform
    dask="parallelized",      # Enable parallel computations with Dask
    output_dtypes=[float]     # Specify output data type
)

# %%
def normalize(data):
    min_val = data.min()
    max_val = data.max()
    return (data - min_val) / (max_val - min_val)

cmip6_tas_norm = normalize(cmip6_high_tas)
cmip6_psl_norm = normalize(cmip6_high_psl)
cmip6_pr_norm = normalize(cmip6_high_pr_log1p)
gmfd_tas_norm = normalize(gmfd_tas['tas'])
gmfd_pr_norm = normalize(gmfd_pr_log1p['prcp'])
elev_dif_norm = normalize(elev_dif['elev'])


# Convert data to NumPy arrays for use in Keras
cmip6_train_tas = cmip6_tas_norm.values
cmip6_train_psl = cmip6_psl_norm.values
cmip6_train_pr = cmip6_pr_norm.values
gmfd_train_pr = gmfd_pr_norm.values
gmfd_train_tas = gmfd_tas_norm.values
elev_dif_norm = elev_dif_norm.values

# %%
print(elev_dif_norm.shape)
print(gmfd_train_tas.shape)
elev_dif_norm_final = np.repeat(elev_dif_norm[np.newaxis :, :], 23741, axis=0)
print(elev_dif_norm_final.shape)
# Out:
# (1, 42, 97)
# (23741, 42, 97)
# (23741, 42, 97)

# %%
plt.imshow(elev_dif_norm_final[10000, :,:], origin='lower', cmap='terrain')

# %% [markdown]
# #### Compute residuals

# %%
import xarray as xr

res_tas = gmfd_train_tas  - cmip6_train_tas
res_pr = gmfd_train_pr  - cmip6_train_pr

# %%
plt.imshow(res_pr[100, :,:], origin='lower', cmap='viridis')

# %% [markdown]
# #### Split the data
# Train set: The first portion of the time period (e.g., 60% of the time series).
# Validation set: The next portion of the time series (e.g., the following 20% of the time series).
# Test set: The final portion of the time series (e.g., the last 20%):

# %%
import pandas as pd
index_2004 = int(np.where(cmip6_tas_norm.time.values == pd.to_datetime('2004-12-31'))[0][0])
index_2009 = int(np.where(cmip6_tas_norm.time.values == pd.to_datetime('2009-12-31'))[0][0])

# %%
# Reshape data to add the channel dimension
cmip6_train_tas_reshaped = cmip6_train_tas[..., np.newaxis]
cmip6_train_pr_reshaped = cmip6_train_psl[..., np.newaxis]
cmip6_train_slp_reshaped = cmip6_train_psl[..., np.newaxis]
elev_dif_norm_reshaped = elev_dif_norm_final[..., np.newaxis]


# Concatenate the reshaped arrays along the last axis
cmip6_train_combined = np.concatenate((cmip6_train_tas_reshaped,cmip6_train_pr_reshaped, cmip6_train_slp_reshaped, elev_dif_norm_reshaped), axis=-1)

gmfd_train_tas_reshaped = gmfd_train_tas[..., np.newaxis]
gmfd_train_pr_reshaped = gmfd_train_pr[..., np.newaxis]

gmfd_train_combined = np.concatenate((gmfd_train_tas_reshaped,gmfd_train_pr_reshaped), axis=-1)

res_tas_reshaped = res_tas[..., np.newaxis]
res_pr_reshaped = res_pr[..., np.newaxis]

res_train_combined = np.concatenate((res_tas_reshaped, res_pr_reshaped), axis=-1)

# %%
# Split the data while preserving the temporal structure
X_train = cmip6_train_combined[:index_2004]
y_train = gmfd_train_combined[:index_2004]
res_train = res_train_combined[:index_2004]

X_val = cmip6_train_combined[index_2004:index_2009]
y_val = gmfd_train_combined[index_2004:index_2009]
res_val = res_train_combined[index_2004:index_2009]

X_test = cmip6_train_combined[index_2009:]
y_test = gmfd_train_combined[index_2009:]
res_test = res_train_combined[index_2009:]


# # Reshape X data to include the temporal dimension
# X_train = np.expand_dims(X_train, axis=1)
# X_val = np.expand_dims(X_val, axis=1)
# X_test = np.expand_dims(X_test, axis=1)

# # Reshape y data to include the temporal dimension
# y_train = np.expand_dims(y_train, axis=1)
# y_val = np.expand_dims(y_val, axis=1)
# y_test = np.expand_dims(y_test, axis=1)

# # Reshape y data to include the temporal dimension
# res_train = np.expand_dims(res_train, axis=1)
# res_val = np.expand_dims(res_val, axis=1)
# res_test = np.expand_dims(res_test, axis=1)

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
print(res_train.shape)
print(res_val.shape)
print(res_test.shape)
# Out:
# (20088, 42, 97, 4)
# (1826, 42, 97, 4)
# (1827, 42, 97, 4)
# (20088, 42, 97, 2)
# (1826, 42, 97, 2)
# (1827, 42, 97, 2)

# %% [markdown]
# #### Create temporal sequences

# %%
def create_temporal_sequences_centered(data, window_size):
    total_seq_length = 2 * window_size + 1
    sequences = []
    
    # For all time points
    for i in range(len(data)):
        sequence = np.zeros((total_seq_length,) + data.shape[1:])
        
        # Handle past values
        for j in range(window_size):
            if i - j >= 0:  # If we have data for this past point
                sequence[window_size - j] = data[i - j]
            else:  # If we don't have data, use the earliest available
                sequence[window_size - j] = data[0]
        
        # Current value
        sequence[window_size] = data[i]
        
        # Handle future values
        for j in range(window_size):
            if i + j + 1 < len(data):  # If we have data for this future point
                sequence[window_size + j + 1] = data[i + j + 1]
            else:  # If we don't have data, use the last available
                sequence[window_size + j + 1] = data[-1]
        
        sequences.append(sequence)
    
    return np.array(sequences)

window_size = 3

# %%
X_train_seq = create_temporal_sequences_centered(X_train, window_size)  
X_val_seq = create_temporal_sequences_centered(X_val, window_size)      
X_test_seq = create_temporal_sequences_centered(X_test, window_size)     
y_train_seq = create_temporal_sequences_centered(y_train, window_size) 
y_val_seq = create_temporal_sequences_centered(y_val, window_size)     
y_test_seq = create_temporal_sequences_centered(y_test, window_size)   

res_train_seq = create_temporal_sequences_centered(res_train, window_size) 
res_val_seq = create_temporal_sequences_centered(res_val, window_size)     
res_test_seq = create_temporal_sequences_centered(res_test, window_size) 

print("X_train shape:", X_train_seq.shape)
print("X_val shape:", X_val_seq.shape)
print("y_train shape:", y_train_seq.shape)
print("y_val shape:", y_val_seq.shape)
print("res_train shape:", res_train_seq.shape)
print("res_val shape:", res_val_seq.shape)
# Out:
# X_train shape: (20088, 7, 42, 97, 4)
# X_val shape: (1826, 7, 42, 97, 4)
# y_train shape: (20088, 7, 42, 97, 2)
# y_val shape: (1826, 7, 42, 97, 2)
# res_train shape: (20088, 7, 42, 97, 2)
# res_val shape: (1826, 7, 42, 97, 2)

# %% [markdown]
# #### Build the VIT-transformenrs (Keras with JAX Backend)

# %%
from keras import ops
from keras.layers import (
    Input, Dense, Dropout, MultiHeadAttention, LayerNormalization,
    Add, Conv3D, Reshape, TimeDistributed, Layer
)
from keras.models import Model, Sequential  
from keras import regularizers
from keras.saving import register_keras_serializable

# **Fourier Positional Encoding Layer** (No changes)
@register_keras_serializable()
class FourierPositionalEncoding(Layer):
    def __init__(self, embed_dim, max_freq=10, **kwargs):
        """
        Fourier positional encoding for spatial and temporal positions.
        Args:
            embed_dim: The dimension of the embeddings.
            max_freq: The maximum frequency for encoding.
        """
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.max_freq = max_freq

    def call(self, inputs):
        """
        Compute Fourier positional encodings and add them to the inputs.
        Args:
            inputs: Input tensor of shape (batch_size, seq_len, embed_dim).
        Returns:
            Tensor with Fourier positional encodings added.
        """
        batch_size, seq_len, embed_dim = ops.shape(inputs)

        # Generate positional values (normalized between 0 and 1)
        positions = ops.linspace(0.0, 1.0, seq_len)

        # Generate frequency bands
        freq_bands = ops.power(2.0, ops.linspace(0.0, self.max_freq, self.embed_dim // 2))

        # Compute Fourier features
        encodings = ops.matmul(ops.expand_dims(positions, axis=-1), ops.expand_dims(freq_bands, axis=0))  # seq_len x (embed_dim // 2)
        sin_encodings = ops.sin(encodings)
        cos_encodings = ops.cos(encodings)

        # Concatenate sine and cosine encodings
        positional_encodings = ops.concatenate([sin_encodings, cos_encodings], axis=-1)  # seq_len x embed_dim
        positional_encodings = ops.expand_dims(positional_encodings, axis=0)  # Add batch dimension
        positional_encodings = ops.broadcast_to(positional_encodings, [batch_size, seq_len, embed_dim])

        # Add positional encodings to inputs
        return inputs + positional_encodings

    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "max_freq": self.max_freq
        })
        return config

# **Residual Multi-Scale Patch Embedding Layer** (Modified num_scales handling)
@register_keras_serializable()
class ResidualMultiScalePatchEmbedding(Layer):
    def __init__(self, patch_size, embed_dim, num_scales=3, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size
        self.embed_dim = embed_dim
        self.num_scales = num_scales

    def build(self, input_shape):
        self.convs = [
            Conv3D(
                filters=self.embed_dim // self.num_scales,
                kernel_size=(k, k, k),
                strides=self.patch_size,
                padding='same',
                name=f"scale_{k}x{k}x{k}"
            )
            for k in range(3, 3 + self.num_scales)  # Dynamic kernel sizes
        ]
        self.fusion = Conv3D(
            filters=self.embed_dim,
            kernel_size=1,
            strides=1,
            padding="same",
            name="multi_scale_fusion"
        )
        self.residual_proj = Conv3D(
            filters=self.embed_dim,
            kernel_size=1,
            strides=self.patch_size,
            padding="same",
            name="residual_projection"
        )

    def call(self, x):
        batch_size = ops.shape(x)[0]
        multi_scale_features = [conv(x) for conv in self.convs]
        combined_features = ops.concatenate(multi_scale_features, axis=-1)
        fused_features = self.fusion(combined_features)
        residual = self.residual_proj(x)
        fused_features += residual
        _, t, h, w, c = ops.shape(fused_features)
        return ops.reshape(fused_features, (batch_size, t * h * w, c))

    def get_config(self):
        config = super().get_config()
        config.update({
            "patch_size": self.patch_size,
            "embed_dim": self.embed_dim,
            "num_scales": self.num_scales
        })
        return config

# **Spatial-Temporal Attention Block** (Simplified with unified attention)
@register_keras_serializable()
class SpatialTemporalAttentionBlock(Layer):
    def __init__(self, embed_dim, num_heads, mlp_dim, dropout, weight_decay, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.mlp_dim = mlp_dim
        self.dropout = dropout
        self.weight_decay = weight_decay

    def build(self, input_shape):
        # Unified Spatial-Temporal Attention
        self.attention = MultiHeadAttention(
            num_heads=self.num_heads,
            key_dim=self.embed_dim // self.num_heads,
            dropout=self.dropout
        )
        # Layer normalizations
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        # Feed-forward network (MLP)
        self.mlp = Sequential([
            Dense(self.mlp_dim, activation="gelu", kernel_regularizer=regularizers.L2(self.weight_decay)),
            Dropout(self.dropout),
            Dense(self.embed_dim, kernel_regularizer=regularizers.L2(self.weight_decay)),
            Dropout(self.dropout)
        ])

    def call(self, inputs):
        attn_output = self.attention(inputs, inputs)  # Unified attention
        x = Add()([inputs, attn_output])
        x = self.layernorm1(x)

        # Feed-forward network (MLP)
        mlp_output = self.mlp(x)
        return self.layernorm2(Add()([x, mlp_output]))

    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "mlp_dim": self.mlp_dim,
            "dropout": self.dropout,
            "weight_decay": self.weight_decay
        })
        return config

# **ViT Transformer** (Modified with dynamic output units and other improvements)
def vit_transformer(input_shape, patch_size, embed_dim, num_heads, transformer_layers, mlp_dim, dropout, weight_decay):
    inputs = Input(shape=input_shape)
    x = ResidualMultiScalePatchEmbedding(patch_size=patch_size, embed_dim=embed_dim, num_scales=3)(inputs)
    x = FourierPositionalEncoding(embed_dim=embed_dim, max_freq=10)(x)

    for _ in range(transformer_layers):
        x = SpatialTemporalAttentionBlock(
            embed_dim=embed_dim, num_heads=num_heads, mlp_dim=mlp_dim, dropout=dropout, weight_decay=weight_decay
        )(x)

    num_time_steps = input_shape[0]
    _, num_patches, embed_dim = ops.shape(x)
    num_spatial_patches = num_patches // num_time_steps
    x = Reshape((num_time_steps, num_spatial_patches * embed_dim))(x)

    x = TimeDistributed(Dense(units=mlp_dim // 2, activation="gelu", kernel_regularizer=regularizers.L2(weight_decay)))(x)
    x = TimeDistributed(Dropout(dropout))(x)
    total_units_per_timestep = input_shape[1] * input_shape[2] * 2 
    x = TimeDistributed(Dense(units=total_units_per_timestep, activation="linear", kernel_regularizer=regularizers.L2(weight_decay)))(x)
    x = TimeDistributed(Reshape(target_shape=(input_shape[1], input_shape[2], 2)))(x) 

    return Model(inputs, x)

# **Example Usage** (Adjusted input shape and num_scales)
input_shape = (7, 42, 97, 4) # Updated input shape 
patch_size = (1, 7, 7)

model = vit_transformer(
    input_shape=input_shape,
    patch_size=patch_size,
    embed_dim=320,
    num_heads=8,
    transformer_layers=6,
    mlp_dim=512,
    dropout=0.2,
    weight_decay=0.001
)

model.summary()
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 7, 42, 97, 4)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_multi_scale_patch_emb… │ (None, 588, 320)       │       195,582 │
# │ (ResidualMultiScalePatchEmbedd… │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fourier_positional_encoding     │ (None, 588, 320)       │             0 │
# │ (FourierPositionalEncoding)     │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ cast (Cast)                     │ (None, 588, 320)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_temporal_attention_blo… │ (None, 588, 320)       │       740,672 │
# │ (SpatialTemporalAttentionBlock) │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_temporal_attention_blo… │ (None, 588, 320)       │       740,672 │
# │ (SpatialTemporalAttentionBlock) │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_temporal_attention_blo… │ (None, 588, 320)       │       740,672 │
# │ (SpatialTemporalAttentionBlock) │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_temporal_attention_blo… │ (None, 588, 320)       │       740,672 │
# │ (SpatialTemporalAttentionBlock) │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_temporal_attention_blo… │ (None, 588, 320)       │       740,672 │
# │ (SpatialTemporalAttentionBlock) │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_temporal_attention_blo… │ (None, 588, 320)       │       740,672 │
# │ (SpatialTemporalAttentionBlock) │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 7, 26880)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 7, 256)         │     6,881,536 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 7, 256)         │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 7, 8148)        │     2,094,036 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_3              │ (None, 7, 42, 97, 2)   │             0 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,615,186 (51.94 MB)
#  Trainable params: 13,615,186 (51.94 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Train the model

# %%
import keras
from keras import ops
from keras.losses import Loss
from keras.saving import register_keras_serializable

@register_keras_serializable()
class ClimateDownscalingLoss(Loss):
    def __init__(self, 
                 spatial_weight_temp=1.0, gradient_weight_temp=0.5, temporal_weight_temp=0.3,
                 spatial_weight_precip=1.0, gradient_weight_precip=0.4, temporal_weight_precip=0.1,
                 mse_weight_temp=1.0, mse_weight_precip=0.5,  
                 observation_weight=1.0,
                 **kwargs):
        super().__init__(**kwargs)
        
        # Weights for temperature
        self.spatial_weight_temp = spatial_weight_temp
        self.gradient_weight_temp = gradient_weight_temp
        self.temporal_weight_temp = temporal_weight_temp
        self.mse_weight_temp = mse_weight_temp
        
        # Weights for precipitation
        self.spatial_weight_precip = spatial_weight_precip
        self.gradient_weight_precip = gradient_weight_precip
        self.temporal_weight_precip = temporal_weight_precip
        self.mse_weight_precip = mse_weight_precip

        self.observation_weight = observation_weight

        self.epsilon = 1e-6

    def call(self, y_true, y_pred, y_low_res=None):
        # Split channels (temperature and precipitation)
        y_true_temp = y_true[:, :, :, :, 0:1]
        y_pred_temp = y_pred[:, :, :, :, 0:1]
        y_true_precip = y_true[:, :, :, :, 1:2]
        y_pred_precip = y_pred[:, :, :, :, 1:2]

        # --- Observation Loss  ---
        observation_loss = (
            self.mse_weight_temp * ops.mean(ops.square(y_true_temp - y_pred_temp)) +
            self.mse_weight_precip * ops.mean(ops.square(y_true_precip - y_pred_precip))
        )

        # --- Regularization Loss (spatial, temporal, physical constraints) ---

        # Spatial Gradient Loss 
        def spatial_gradients(x):
            dy = x[:, :, 1:, :, :] - x[:, :, :-1, :, :]
            dx = x[:, :, :, 1:, :] - x[:, :, :, :-1, :]
            return dy, dx

        # Spatial gradients for temperature
        _, true_dx_temp = spatial_gradients(y_true_temp)
        _, pred_dx_temp = spatial_gradients(y_pred_temp)

        spatial_gradient_loss_temp = ops.mean(ops.square(true_dx_temp - pred_dx_temp)) + self.epsilon

        # Spatial gradients for precipitation
        _, true_dx_precip = spatial_gradients(y_true_precip)
        _, pred_dx_precip = spatial_gradients(y_pred_precip)

        spatial_gradient_loss_precip = ops.mean(ops.square(true_dx_precip - pred_dx_precip)) + self.epsilon

        # Temporal Gradient Loss
        def temporal_gradients(x):
            dt = x[:, 1:, :, :, :] - x[:, :-1, :, :, :]
            return dt

        # Temporal gradients for temperature
        true_dt_temp = temporal_gradients(y_true_temp)
        pred_dt_temp = temporal_gradients(y_pred_temp)

        temporal_gradient_loss_temp = ops.mean(ops.square(true_dt_temp - pred_dt_temp)) + self.epsilon

        # Temporal gradients for precipitation
        true_dt_precip = temporal_gradients(y_true_precip)
        pred_dt_precip = temporal_gradients(y_pred_precip)

        temporal_gradient_loss_precip = ops.mean(ops.square(true_dt_precip - pred_dt_precip)) + self.epsilon

        regularization_loss = (
            self.spatial_weight_temp * spatial_gradient_loss_temp
            + self.temporal_weight_temp * temporal_gradient_loss_temp
            + self.spatial_weight_precip * spatial_gradient_loss_precip
            + self.temporal_weight_precip * temporal_gradient_loss_precip
            # + other regularization terms... (add other constraints here)
        )

        # --- Total Loss ---
        total_loss = (
            self.observation_weight * observation_loss +
            regularization_loss
        )

        return total_loss

    def get_config(self):
        config = super().get_config()
        config.update({
            "spatial_weight_temp": self.spatial_weight_temp,
            "gradient_weight_temp": self.gradient_weight_temp,
            "temporal_weight_temp": self.temporal_weight_temp,
            "mse_weight_temp": self.mse_weight_temp,
            "spatial_weight_precip": self.spatial_weight_precip,
            "gradient_weight_precip": self.gradient_weight_precip,
            "temporal_weight_precip": self.temporal_weight_precip,
            "mse_weight_precip": self.mse_weight_precip,
            "observation_weight": self.observation_weight
        })
        return config

# %%
print(X_train_seq.shape)
# Out:
# (20088, 7, 42, 97, 4)

# %%
from keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint, TerminateOnNaN

# Model setup
input_shape = (7, 42, 97, 4)
patch_size = (1, 7, 7)


model = vit_transformer(
    input_shape=input_shape,
    patch_size=patch_size,
    embed_dim=300,
    num_heads=10,
    transformer_layers=8,
    mlp_dim=512,
    dropout=0.2,
    weight_decay=0.01
)


climate_loss = ClimateDownscalingLoss(
    spatial_weight_temp=0.1,
    gradient_weight_temp=0.05,
    temporal_weight_temp=0.05,
    spatial_weight_precip=0.5,
    gradient_weight_precip=0.05,
    temporal_weight_precip=0.05,
    mse_weight_temp=1.0,
    mse_weight_precip=1.0,
    observation_weight=0.01

)

# Learning rate schedule
initial_learning_rate = 1e-4
lr_schedule = tf.keras.optimizers.schedules.CosineDecayRestarts(
    initial_learning_rate=initial_learning_rate,
    first_decay_steps=50,
    t_mul=2.0,
    m_mul=0.8,
    alpha=1e-6
)

# Optimizer
optimizer = AdamW(learning_rate=lr_schedule, weight_decay=1e-5)


# Compile model
model.compile(
    optimizer=optimizer,
    loss=climate_loss,
    metrics=[
        tf.keras.metrics.MeanAbsoluteError(),
        tf.keras.metrics.RootMeanSquaredError()
    ]
)

# Callbacks
class LRLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f'\nLearning rate for epoch {epoch+1} is {lr}')

callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=20,
        restore_best_weights=True,
        min_delta=1e-4
    ),
    ModelCheckpoint(
        filepath='models/vit_transformer_best_model.keras',
        monitor='val_loss',
        save_best_only=True,
        save_weights_only=False,
        mode='min',
        verbose=1
    ),
    TerminateOnNaN(),
    LRLogger()
]

# Training
history = model.fit(
    X_train_seq, res_train_seq,
    validation_data=(X_val_seq, res_val_seq),
    epochs=500,
    batch_size=100,
    callbacks=callbacks,
    verbose=1,
    shuffle=False
)

# Print results
print("\nTraining completed.")
best_val_loss = min(history.history['val_loss'])
best_epoch = history.history['val_loss'].index(best_val_loss) + 1
print(f"Best validation loss: {best_val_loss:.6f} at epoch {best_epoch}")
# Out:
# Epoch 1/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - loss: 61.5717 - mean_absolute_error: 0.1103 - root_mean_squared_error: 0.1752
# Epoch 1: val_loss improved from inf to 45.03180, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 1 is 5.426925522174459e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 143s 608ms/step - loss: 61.5419 - mean_absolute_error: 0.1103 - root_mean_squared_error: 0.1752 - val_loss: 45.0318 - val_mean_absolute_error: 0.1040 - val_root_mean_squared_error: 0.1703
# Epoch 2/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 41.8818 - mean_absolute_error: 0.1032 - root_mean_squared_error: 0.1684
# Epoch 2: val_loss improved from 45.03180 to 35.30696, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 2 is 4.9094569322991516e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 97s 404ms/step - loss: 41.8720 - mean_absolute_error: 0.1033 - root_mean_squared_error: 0.1684 - val_loss: 35.3070 - val_mean_absolute_error: 0.1033 - val_root_mean_squared_error: 0.1701
# Epoch 3/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 32.4451 - mean_absolute_error: 0.1025 - root_mean_squared_error: 0.1682
# Epoch 3: val_loss improved from 35.30696 to 26.90163, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 3 is 1.5248888705660178e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 32.4341 - mean_absolute_error: 0.1025 - root_mean_squared_error: 0.1682 - val_loss: 26.9016 - val_mean_absolute_error: 0.1024 - val_root_mean_squared_error: 0.1699
# Epoch 4/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 26.4103 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1680
# Epoch 4: val_loss improved from 26.90163 to 23.79690, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 4 is 4.0501306224176195e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 403ms/step - loss: 26.4079 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1680 - val_loss: 23.7969 - val_mean_absolute_error: 0.1023 - val_root_mean_squared_error: 0.1698
# Epoch 5/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 22.0028 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1679
# Epoch 5: val_loss improved from 23.79690 to 17.53160, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 5 is 3.152162133166443e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 21.9948 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1679 - val_loss: 17.5316 - val_mean_absolute_error: 0.1022 - val_root_mean_squared_error: 0.1697
# Epoch 6/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 16.5457 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1678
# Epoch 6: val_loss improved from 17.53160 to 14.31097, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 6 is 1.60125104037724e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 16.5416 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1678 - val_loss: 14.3110 - val_mean_absolute_error: 0.1022 - val_root_mean_squared_error: 0.1696
# Epoch 7/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 13.9246 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1677
# Epoch 7: val_loss improved from 14.31097 to 13.21968, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 7 is 3.1453006342440507e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 402ms/step - loss: 13.9232 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1677 - val_loss: 13.2197 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1695
# Epoch 8/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 13.1508 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1677
# Epoch 8: val_loss improved from 13.21968 to 12.00029, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 8 is 3.266193779704271e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 402ms/step - loss: 13.1500 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1677 - val_loss: 12.0003 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1695
# Epoch 9/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 11.1351 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1676
# Epoch 9: val_loss improved from 12.00029 to 8.82896, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 9 is 3.069473522007745e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 11.1311 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1676 - val_loss: 8.8290 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1693
# Epoch 10/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 8.2236 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1674
# Epoch 10: val_loss improved from 8.82896 to 6.63751, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 10 is 2.6527308738257055e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 8.2208 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1674 - val_loss: 6.6375 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1692
# Epoch 11/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 6.2335 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1673
# Epoch 11: val_loss improved from 6.63751 to 5.19269, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 11 is 2.0800388880191098e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 402ms/step - loss: 6.2317 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1673 - val_loss: 5.1927 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1691
# Epoch 12/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 4.9362 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1672
# Epoch 12: val_loss improved from 5.19269 to 4.28936, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 12 is 1.4394474055142478e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 402ms/step - loss: 4.9350 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1672 - val_loss: 4.2894 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1690
# Epoch 13/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 4.1377 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1672
# Epoch 13: val_loss improved from 4.28936 to 3.76949, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 13 is 8.294456308594458e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 402ms/step - loss: 4.1370 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1672 - val_loss: 3.7695 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1690
# Epoch 14/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 3.6913 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1671
# Epoch 14: val_loss improved from 3.76949 to 3.51649, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 14 is 3.438196839136412e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 402ms/step - loss: 3.6910 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1671 - val_loss: 3.5165 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1689
# Epoch 15/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 3.4874 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1671
# Epoch 15: val_loss improved from 3.51649 to 3.43540, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 15 is 5.723323806146566e-07
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 402ms/step - loss: 3.4873 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1671 - val_loss: 3.4354 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1689
# Epoch 16/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 3.4246 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1671
# Epoch 16: val_loss improved from 3.43540 to 3.04673, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 16 is 2.618696856044849e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 402ms/step - loss: 3.4243 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1671 - val_loss: 3.0467 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1689
# Epoch 17/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 2.7888 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1670
# Epoch 17: val_loss improved from 3.04673 to 2.10398, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 17 is 2.57667463877505e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 402ms/step - loss: 2.7876 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1670 - val_loss: 2.1040 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1687
# Epoch 18/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 1.9238 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1669
# Epoch 18: val_loss improved from 2.10398 to 1.44764, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 18 is 2.485516700056803e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 402ms/step - loss: 1.9230 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1669 - val_loss: 1.4476 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1686
# Epoch 19/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 1.3234 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1668
# Epoch 19: val_loss improved from 1.44764 to 0.99629, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 19 is 2.348761193384307e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 402ms/step - loss: 1.3228 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1668 - val_loss: 0.9963 - val_mean_absolute_error: 0.1020 - val_root_mean_squared_error: 0.1685
# Epoch 20/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.9116 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1667
# Epoch 20: val_loss improved from 0.99629 to 0.68931, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 20 is 2.171716070874381e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 402ms/step - loss: 0.9112 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1667 - val_loss: 0.6893 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1684
# Epoch 21/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.6321 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1666
# Epoch 21: val_loss improved from 0.68931 to 0.48235, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 21 is 1.9612530633674507e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.6319 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1666 - val_loss: 0.4824 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1683
# Epoch 22/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.4440 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1665
# Epoch 22: val_loss improved from 0.48235 to 0.34365, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 22 is 1.7255409648915592e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.4438 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1665 - val_loss: 0.3437 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1682
# Epoch 23/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.3180 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1665
# Epoch 23: val_loss improved from 0.34365 to 0.25100, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 23 is 1.473728573637784e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.3179 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1665 - val_loss: 0.2510 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1681
# Epoch 24/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.2339 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1664
# Epoch 24: val_loss improved from 0.25100 to 0.18920, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 24 is 1.215589595599534e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.2339 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1664 - val_loss: 0.1892 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1681
# Epoch 25/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.1779 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1664
# Epoch 25: val_loss improved from 0.18920 to 0.14806, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 25 is 9.611432933882473e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 402ms/step - loss: 0.1778 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1664 - val_loss: 0.1481 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1680
# Epoch 26/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.1406 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663
# Epoch 26: val_loss improved from 0.14806 to 0.12082, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 26 is 7.20265604151183e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 402ms/step - loss: 0.1405 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663 - val_loss: 0.1208 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1680
# Epoch 27/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.1159 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663
# Epoch 27: val_loss improved from 0.12082 to 0.10309, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 27 is 5.0230582044401325e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 401ms/step - loss: 0.1159 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663 - val_loss: 0.1031 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1680
# Epoch 28/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.1000 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663
# Epoch 28: val_loss improved from 0.10309 to 0.09197, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 28 is 3.157237119934584e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.1000 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663 - val_loss: 0.0920 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1680
# Epoch 29/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - loss: 0.0902 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663
# Epoch 29: val_loss improved from 0.09197 to 0.08555, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 29 is 1.6776117290387968e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0902 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663 - val_loss: 0.0855 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1679
# Epoch 30/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0847 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663
# Epoch 30: val_loss improved from 0.08555 to 0.08245, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 30 is 6.416113881041358e-07
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 401ms/step - loss: 0.0846 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663 - val_loss: 0.0825 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1679
# Epoch 31/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0822 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663
# Epoch 31: val_loss improved from 0.08245 to 0.08151, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 31 is 8.944683771787716e-08
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0822 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663 - val_loss: 0.0815 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1679
# Epoch 32/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0808 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663
# Epoch 32: val_loss improved from 0.08151 to 0.05823, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 32 is 2.0963105691647365e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0808 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1663 - val_loss: 0.0582 - val_mean_absolute_error: 0.1021 - val_root_mean_squared_error: 0.1679
# Epoch 33/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0482 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1662
# Epoch 33: val_loss improved from 0.05823 to 0.02587, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 33 is 2.0870584551175573e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 402ms/step - loss: 0.0482 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1662 - val_loss: 0.0259 - val_mean_absolute_error: 0.1022 - val_root_mean_squared_error: 0.1678
# Epoch 34/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0218 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1662
# Epoch 34: val_loss improved from 0.02587 to 0.01264, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 34 is 2.0677050941890224e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 402ms/step - loss: 0.0218 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1662 - val_loss: 0.0126 - val_mean_absolute_error: 0.1022 - val_root_mean_squared_error: 0.1677
# Epoch 35/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0111 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1661
# Epoch 35: val_loss improved from 0.01264 to 0.00750, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 35 is 2.0384387368024972e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0111 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1661 - val_loss: 0.0075 - val_mean_absolute_error: 0.1022 - val_root_mean_squared_error: 0.1677
# Epoch 36/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0070 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1660
# Epoch 36: val_loss improved from 0.00750 to 0.00562, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 36 is 1.9995440572421367e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0070 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1660 - val_loss: 0.0056 - val_mean_absolute_error: 0.1022 - val_root_mean_squared_error: 0.1676
# Epoch 37/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0055 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1660
# Epoch 37: val_loss improved from 0.00562 to 0.00497, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 37 is 1.9513993846219854e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0055 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1660 - val_loss: 0.0050 - val_mean_absolute_error: 0.1022 - val_root_mean_squared_error: 0.1675
# Epoch 38/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0050 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1659
# Epoch 38: val_loss improved from 0.00497 to 0.00477, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 38 is 1.894473022873178e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0050 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1659 - val_loss: 0.0048 - val_mean_absolute_error: 0.1023 - val_root_mean_squared_error: 0.1675
# Epoch 39/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0048 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1659
# Epoch 39: val_loss improved from 0.00477 to 0.00471, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 39 is 1.8293186955447846e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0048 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1659 - val_loss: 0.0047 - val_mean_absolute_error: 0.1023 - val_root_mean_squared_error: 0.1674
# Epoch 40/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1658
# Epoch 40: val_loss improved from 0.00471 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 40 is 1.7565701597267966e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1659 - val_loss: 0.0047 - val_mean_absolute_error: 0.1023 - val_root_mean_squared_error: 0.1674
# Epoch 41/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1658
# Epoch 41: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 41 is 1.6769350414856865e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1658 - val_loss: 0.0047 - val_mean_absolute_error: 0.1023 - val_root_mean_squared_error: 0.1673
# Epoch 42/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1658
# Epoch 42: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 42 is 1.5911879527753634e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0048 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1658 - val_loss: 0.0047 - val_mean_absolute_error: 0.1023 - val_root_mean_squared_error: 0.1673
# Epoch 43/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657
# Epoch 43: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 43 is 1.5001629567754267e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1658 - val_loss: 0.0047 - val_mean_absolute_error: 0.1024 - val_root_mean_squared_error: 0.1673
# Epoch 44/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657
# Epoch 44: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 44 is 1.404745454946482e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657 - val_loss: 0.0047 - val_mean_absolute_error: 0.1024 - val_root_mean_squared_error: 0.1672
# Epoch 45/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657
# Epoch 45: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 45 is 1.3058635747172479e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 402ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657 - val_loss: 0.0047 - val_mean_absolute_error: 0.1024 - val_root_mean_squared_error: 0.1672
# Epoch 46/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657
# Epoch 46: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 46 is 1.2044791415755545e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657 - val_loss: 0.0047 - val_mean_absolute_error: 0.1024 - val_root_mean_squared_error: 0.1672
# Epoch 47/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657
# Epoch 47: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 47 is 1.1015783233778255e-05
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0048 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1657 - val_loss: 0.0047 - val_mean_absolute_error: 0.1024 - val_root_mean_squared_error: 0.1671
# Epoch 48/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 48: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 48 is 9.981620378799894e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1024 - val_root_mean_squared_error: 0.1671
# Epoch 49/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 49: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 49 is 8.952362167959056e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 401ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1024 - val_root_mean_squared_error: 0.1671
# Epoch 50/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 50: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 50 is 7.938020210849407e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 401ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1025 - val_root_mean_squared_error: 0.1671
# Epoch 51/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 51: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 51 is 6.948461026447549e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 401ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1025 - val_root_mean_squared_error: 0.1671
# Epoch 52/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 52: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 52 is 5.9933100713393355e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1025 - val_root_mean_squared_error: 0.1671
# Epoch 53/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 53: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 53 is 5.081858112763584e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1025 - val_root_mean_squared_error: 0.1671
# Epoch 54/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 54: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 54 is 4.222970857183999e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1025 - val_root_mean_squared_error: 0.1671
# Epoch 55/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 55: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 55 is 3.42500271343335e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 401ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1025 - val_root_mean_squared_error: 0.1670
# Epoch 56/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 56: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 56 is 2.695715529257211e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1025 - val_root_mean_squared_error: 0.1670
# Epoch 57/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 57: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 57 is 2.042203091707993e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1025 - val_root_mean_squared_error: 0.1670
# Epoch 58/500
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656
# Epoch 58: val_loss improved from 0.00469 to 0.00469, saving model to models/vit_transformer_best_model.keras
#
# Learning rate for epoch 58 is 1.4708221257750524e-06
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 84s 400ms/step - loss: 0.0048 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1656 - val_loss: 0.0047 - val_mean_absolute_error: 0.1025 - val_root_mean_squared_error: 0.1670
#
# Training completed.
# Best validation loss: 0.004686 at epoch 58

# %%
import matplotlib.pyplot as plt

# Assuming 'history' is the result of model.fit()
plt.figure(figsize=(8, 4))

# Plotting the training and validation loss with log scale on y-axis
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

# Title and labels
plt.title('Training and Validation Loss Over Epochs (Log Scale)')
plt.xlabel('Epochs')
plt.ylabel('Loss (Log Scale)')

# Set y-axis to log scale
#plt.yscale('log')

# Optional: Set y-axis limits (adjust these as needed for your data)
#plt.ylim(0,1)  # Example: Set limits from 0.001 to 10

# Show legend
plt.legend()

# Add grid for clarity
plt.grid(which='both')  # Add grid for both major and minor ticks

# Show the plot
plt.show()

# %% [markdown]
# #### Evaluate the model on validation data

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
# Load the model

from keras.models import load_model

model_saved = load_model('models/vit_transformer_best_model.keras')

# %%
# Get the mean and std from the training set for denormalization
cmip6_high_tas_min = cmip6_high_tas.min().values
cmip6_high_tas_max = cmip6_high_tas.max().values
cmip6_high_pr_min = cmip6_high_pr_log1p.min().values
cmip6_high_pr_max = cmip6_high_pr_log1p.max().values

# Get the mean and std from the training set for denormalization
gmfd_min_tas = gmfd_tas['tas'].min().values
gmfd_max_tas = gmfd_tas['tas'].max().values
gmfd_min_pr = gmfd_pr_log1p['prcp'].min().values
gmfd_max_pr = gmfd_pr_log1p['prcp'].max().values


# Generate predictions on validation data
y_pred = model_saved.predict(X_test_seq)
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 131ms/step

# %%
# put back the residuals
y_pred_tas = X_test_seq[:,window_size,:,:,0] +  y_pred[:,window_size,:,:,0]
y_pred_pr = X_test_seq[:,window_size,:,:,1] +  y_pred[:,window_size,:,:,1]

print(y_pred.shape)
print(y_test_seq[:,window_size,:,:,0].shape)
# Back-transform the predictions for evaluation
y_test_denorm_tas = y_test_seq[:,window_size,:,:,0] * (gmfd_max_tas - gmfd_min_tas) + gmfd_min_tas
y_pred_denorm_tas = y_pred_tas * (cmip6_high_tas_max - cmip6_high_tas_min) + cmip6_high_tas_min

y_test_denorm_pr = y_test_seq[:,window_size,:,:,1] * (gmfd_max_pr - gmfd_min_pr) + gmfd_min_pr
y_pred_denorm_pr = y_pred_pr * (cmip6_high_pr_max - cmip6_high_pr_min) + cmip6_high_pr_min
# back transform from log1p
y_pred_denorm_pr_back = np.expm1(y_pred_denorm_pr)
y_test_denorm_pr_back = np.expm1(y_test_denorm_pr)
y_pred_denorm_pr_back[y_pred_denorm_pr_back < 0] = 0
# Out:
# (1827, 7, 42, 97, 2)
# (1827, 42, 97)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

def evaluate_and_plot(y_test_denorm, y_pred_denorm, title="Predicted vs Actual"):
    """
    Calculates RMSE, MAE, and correlation, and generates a scatter plot
    of predicted vs. actual values.

    Args:
        y_test_denorm (np.ndarray): The actual/observed (denormalized) values.
        y_pred_denorm (np.ndarray): The predicted (denormalized) values.
        title (str, optional): The title of the plot. Defaults to "Predicted vs Actual".
    """

    # Calculate RMSE, MAE, and correlation
    rmse = np.sqrt(mean_squared_error(y_test_denorm.flatten(), y_pred_denorm.flatten()))
    mae = mean_absolute_error(y_test_denorm.flatten(), y_pred_denorm.flatten())
    correlation = np.corrcoef(y_test_denorm.flatten(), y_pred_denorm.flatten())[0,1]

    # Create the plot
    plt.figure(figsize=(8, 8))
    plt.grid(True, linestyle='--', alpha=0.7)  # Add grid
    plt.scatter(y_test_denorm.flatten(), y_pred_denorm.flatten(), alpha=0.5)
    plt.xlabel('Actual Values (GMFD)')
    plt.ylabel('Predicted Values')
    plt.title(f'{title} (Back-transformed)')
    plt.plot([y_test_denorm.min(), y_test_denorm.max()],
            [y_test_denorm.min(), y_test_denorm.max()], 'r--')

    # Add RMSE, MAE, and correlation text to the upper left
    plt.text(0.05, 0.95, f'RMSE: {rmse:.3f}\nMAE: {mae:.3f}\nCorr: {correlation:.3f}',
            transform=plt.gca().transAxes,
            verticalalignment='top',
            bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

    plt.show()

evaluate_and_plot(y_test_denorm_tas, y_pred_denorm_tas, title="Temperature")
evaluate_and_plot(y_test_denorm_pr_back, y_pred_denorm_pr_back, title="Precipitation")

# %%
evaluate_and_plot( gmfd_pr['prcp'].values[index_2009:], cmip6_high_pr.values[index_2009:], title="Precipitation")

# %% [markdown]
# #### Train the on All Data
# Train the model on all the data (no splitting)

# %%
X_all = np.concatenate((X_train_seq, X_val_seq, X_test_seq), axis=0)
y_all = np.concatenate((y_train_seq, y_val_seq, y_test_seq), axis=0)
res_all = np.concatenate((res_train_seq, res_val_seq, res_test_seq), axis=0)

# %%
import tensorflow as tf
from keras.optimizers import AdamW
from keras.callbacks import EarlyStopping, ModelCheckpoint, TerminateOnNaN


# Model setup
input_shape = (7, 42, 97, 4)
patch_size = (7, 7, 7)

model = vit_transformer(
    input_shape=input_shape,
    patch_size=patch_size,
    embed_dim=300,
    num_heads=10,
    transformer_layers=8,
    mlp_dim=512,
    dropout=0.2,
    weight_decay=0.01
)


climate_loss = ClimateDownscalingLoss(
    spatial_weight_temp=0.1,
    gradient_weight_temp=0.5,
    temporal_weight_temp=0.5,
    spatial_weight_precip=0.5,
    gradient_weight_precip=0.5,
    temporal_weight_precip=0.05,
    mse_weight_temp=1.0,
    mse_weight_precip=1.0,
    observation_weight=0.3

)


# Training parameters
epochs = 500
batch_size = 100

# Learning rate schedule using CosineDecayRestarts
initial_learning_rate = 1e-4
lr_schedule = tf.keras.optimizers.schedules.CosineDecayRestarts(
    initial_learning_rate=initial_learning_rate,
    first_decay_steps=50,  # Number of steps in the first cycle
    t_mul=2.0,             # Cycle length multiplier
    m_mul=0.8,             # Multiplier for the max learning rate
    alpha=1e-6             # Minimum learning rate
)

# Optimizer with learning rate schedule
optimizer = AdamW(learning_rate=lr_schedule, weight_decay=1e-5)


# Compile the model
model.compile(
    optimizer=optimizer,
    loss=climate_loss,
    metrics=[
        tf.keras.metrics.MeanAbsoluteError(),
        tf.keras.metrics.RootMeanSquaredError()
    ]
)

# Custom callback to log learning rate
class LRLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer.learning_rate
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        print(f'\nLearning rate for epoch {epoch+1} is {lr}')

# Callbacks for training
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=20,
        restore_best_weights=True,
        min_delta=1e-4
    ),
    ModelCheckpoint(
        filepath='models/vit_transformer_final_model.keras',
        monitor='val_loss',
        save_best_only=True,
        save_weights_only=False,
        mode='min',
        verbose=1
    ),
    TerminateOnNaN(),
    LRLogger()  # Add the learning rate logger
]


# Perform training
history = model.fit(
    X_all, res_all,
    validation_split=0.2,
    epochs=epochs,
    batch_size=batch_size,
    callbacks=callbacks,
    verbose=1,
    shuffle=False  # Sequential data training
)

# Summarize results
print("\nTraining completed.")
best_val_loss = min(history.history['val_loss'])
best_epoch = history.history['val_loss'].index(best_val_loss) + 1
print(f"Best validation loss: {best_val_loss:.6f} at epoch {best_epoch}")
# Out:
# Epoch 1/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 62.7196 - mean_absolute_error: 0.1180 - root_mean_squared_error: 0.1809
# Epoch 1: val_loss improved from inf to 47.96973, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 1 is 5.78885859314545e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 184s 455ms/step - loss: 62.6918 - mean_absolute_error: 0.1179 - root_mean_squared_error: 0.1809 - val_loss: 47.9697 - val_mean_absolute_error: 0.1052 - val_root_mean_squared_error: 0.1714
# Epoch 2/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 44.3748 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1681
# Epoch 2: val_loss improved from 47.96973 to 38.31924, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 2 is 5.049271946951058e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 19s 34ms/step - loss: 44.3636 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1681 - val_loss: 38.3192 - val_mean_absolute_error: 0.1032 - val_root_mean_squared_error: 0.1706
# Epoch 3/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 35.0923 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1674
# Epoch 3: val_loss improved from 38.31924 to 28.36095, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 3 is 2.1595356099692393e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 35.0786 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1674 - val_loss: 28.3610 - val_mean_absolute_error: 0.1027 - val_root_mean_squared_error: 0.1701
# Epoch 4/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 27.5987 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1670
# Epoch 4: val_loss improved from 28.36095 to 26.30985, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 4 is 4.094426971799935e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 27.5940 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1670 - val_loss: 26.3098 - val_mean_absolute_error: 0.1027 - val_root_mean_squared_error: 0.1700
# Epoch 5/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 24.3259 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1669
# Epoch 5: val_loss improved from 26.30985 to 19.23982, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 5 is 3.4961611917153625e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 24.3070 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1669 - val_loss: 19.2398 - val_mean_absolute_error: 0.1027 - val_root_mean_squared_error: 0.1696
# Epoch 6/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 18.0611 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1665
# Epoch 6: val_loss improved from 19.23982 to 15.27361, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 6 is 2.1284119742704706e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 18.0557 - mean_absolute_error: 0.1012 - root_mean_squared_error: 0.1665 - val_loss: 15.2736 - val_mean_absolute_error: 0.1027 - val_root_mean_squared_error: 0.1693
# Epoch 7/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 14.7261 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1664
# Epoch 7: val_loss improved from 15.27361 to 13.59602, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 7 is 7.179396790893872e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 14.7238 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1664 - val_loss: 13.5960 - val_mean_absolute_error: 0.1027 - val_root_mean_squared_error: 0.1692
# Epoch 8/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 13.4524 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1663
# Epoch 8: val_loss improved from 13.59602 to 13.26396, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 8 is 1.4205785960511026e-07
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 13.4515 - mean_absolute_error: 0.1013 - root_mean_squared_error: 0.1663 - val_loss: 13.2640 - val_mean_absolute_error: 0.1027 - val_root_mean_squared_error: 0.1692
# Epoch 9/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 12.7692 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1662
# Epoch 9: val_loss improved from 13.26396 to 10.32914, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 9 is 3.196617799686984e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 12.7609 - mean_absolute_error: 0.1014 - root_mean_squared_error: 0.1662 - val_loss: 10.3291 - val_mean_absolute_error: 0.1028 - val_root_mean_squared_error: 0.1690
# Epoch 10/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.6294 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1661
# Epoch 10: val_loss improved from 10.32914 to 7.77313, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 10 is 2.904907421889182e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 9.6260 - mean_absolute_error: 0.1015 - root_mean_squared_error: 0.1661 - val_loss: 7.7731 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1688
# Epoch 11/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.2872 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1659
# Epoch 11: val_loss improved from 7.77313 to 6.01635, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 11 is 2.43896460311157e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 7.2849 - mean_absolute_error: 0.1016 - root_mean_squared_error: 0.1659 - val_loss: 6.0163 - val_mean_absolute_error: 0.1029 - val_root_mean_squared_error: 0.1686
# Epoch 12/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.6918 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1658
# Epoch 12: val_loss improved from 6.01635 to 4.85627, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 12 is 1.8628891577307163e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 5.6902 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1658 - val_loss: 4.8563 - val_mean_absolute_error: 0.1030 - val_root_mean_squared_error: 0.1685
# Epoch 13/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.6503 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1657
# Epoch 13: val_loss improved from 4.85627 to 4.12924, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 13 is 1.2559318599353698e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 4.6484 - mean_absolute_error: 0.1017 - root_mean_squared_error: 0.1657 - val_loss: 4.1292 - val_mean_absolute_error: 0.1031 - val_root_mean_squared_error: 0.1684
# Epoch 14/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 4.0068 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1656
# Epoch 14: val_loss improved from 4.12924 to 3.71255, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 14 is 7.015919043804739e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 4.0063 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1656 - val_loss: 3.7125 - val_mean_absolute_error: 0.1031 - val_root_mean_squared_error: 0.1684
# Epoch 15/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.6501 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1656
# Epoch 15: val_loss improved from 3.71255 to 3.51399, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 15 is 2.761299110833226e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 3.6498 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1656 - val_loss: 3.5140 - val_mean_absolute_error: 0.1031 - val_root_mean_squared_error: 0.1683
# Epoch 16/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.4915 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1656
# Epoch 16: val_loss improved from 3.51399 to 3.45459, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 16 is 3.807674197710265e-07
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 3.4915 - mean_absolute_error: 0.1018 - root_mean_squared_error: 0.1656 - val_loss: 3.4546 - val_mean_absolute_error: 0.1031 - val_root_mean_squared_error: 0.1683
# Epoch 17/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.4367 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1656
# Epoch 17: val_loss improved from 3.45459 to 2.99073, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 17 is 2.617406870271199e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 3.4362 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1656 - val_loss: 2.9907 - val_mean_absolute_error: 0.1031 - val_root_mean_squared_error: 0.1683
# Epoch 18/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.7522 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1655
# Epoch 18: val_loss improved from 2.99073 to 2.11218, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 18 is 2.575668788110828e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 2.7498 - mean_absolute_error: 0.1019 - root_mean_squared_error: 0.1655 - val_loss: 2.1122 - val_mean_absolute_error: 0.1032 - val_root_mean_squared_error: 0.1682
# Epoch 19/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9422 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1654
# Epoch 19: val_loss improved from 2.11218 to 1.48862, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 19 is 2.4900455808348577e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 1.9406 - mean_absolute_error: 0.1020 - root_mean_squared_error: 0.1655 - val_loss: 1.4886 - val_mean_absolute_error: 0.1033 - val_root_mean_squared_error: 0.1681
# Epoch 20/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.3682 - mean_absolute_error: 0.1021 - root_mean_squared_error: 0.1654
# Epoch 20: val_loss improved from 1.48862 to 1.05078, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 20 is 2.363507812162136e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 1.3676 - mean_absolute_error: 0.1021 - root_mean_squared_error: 0.1654 - val_loss: 1.0508 - val_mean_absolute_error: 0.1034 - val_root_mean_squared_error: 0.1680
# Epoch 21/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9667 - mean_absolute_error: 0.1022 - root_mean_squared_error: 0.1653
# Epoch 21: val_loss improved from 1.05078 to 0.74638, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 21 is 2.2004455127472254e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.9663 - mean_absolute_error: 0.1022 - root_mean_squared_error: 0.1653 - val_loss: 0.7464 - val_mean_absolute_error: 0.1034 - val_root_mean_squared_error: 0.1679
# Epoch 22/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6884 - mean_absolute_error: 0.1023 - root_mean_squared_error: 0.1653
# Epoch 22: val_loss improved from 0.74638 to 0.53645, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 22 is 2.0065158749094096e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 0.6879 - mean_absolute_error: 0.1023 - root_mean_squared_error: 0.1653 - val_loss: 0.5365 - val_mean_absolute_error: 0.1035 - val_root_mean_squared_error: 0.1679
# Epoch 23/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4965 - mean_absolute_error: 0.1024 - root_mean_squared_error: 0.1652
# Epoch 23: val_loss improved from 0.53645 to 0.39251, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 23 is 1.7884469851628257e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.4961 - mean_absolute_error: 0.1024 - root_mean_squared_error: 0.1653 - val_loss: 0.3925 - val_mean_absolute_error: 0.1036 - val_root_mean_squared_error: 0.1678
# Epoch 24/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3649 - mean_absolute_error: 0.1024 - root_mean_squared_error: 0.1652
# Epoch 24: val_loss improved from 0.39251 to 0.29415, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 24 is 1.5538044037416677e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.3648 - mean_absolute_error: 0.1024 - root_mean_squared_error: 0.1652 - val_loss: 0.2942 - val_mean_absolute_error: 0.1036 - val_root_mean_squared_error: 0.1678
# Epoch 25/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2752 - mean_absolute_error: 0.1025 - root_mean_squared_error: 0.1652
# Epoch 25: val_loss improved from 0.29415 to 0.22705, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 25 is 1.3107286892800005e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.2751 - mean_absolute_error: 0.1025 - root_mean_squared_error: 0.1652 - val_loss: 0.2270 - val_mean_absolute_error: 0.1036 - val_root_mean_squared_error: 0.1678
# Epoch 26/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2139 - mean_absolute_error: 0.1025 - root_mean_squared_error: 0.1652
# Epoch 26: val_loss improved from 0.22705 to 0.18133, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 26 is 1.0676529748183336e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.2139 - mean_absolute_error: 0.1025 - root_mean_squared_error: 0.1652 - val_loss: 0.1813 - val_mean_absolute_error: 0.1037 - val_root_mean_squared_error: 0.1677
# Epoch 27/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1723 - mean_absolute_error: 0.1025 - root_mean_squared_error: 0.1652
# Epoch 27: val_loss improved from 0.18133 to 0.15027, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 27 is 8.330103933971755e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.1722 - mean_absolute_error: 0.1025 - root_mean_squared_error: 0.1652 - val_loss: 0.1503 - val_mean_absolute_error: 0.1037 - val_root_mean_squared_error: 0.1677
# Epoch 28/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1440 - mean_absolute_error: 0.1026 - root_mean_squared_error: 0.1652
# Epoch 28: val_loss improved from 0.15027 to 0.12938, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 28 is 6.149415036505914e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 0.1440 - mean_absolute_error: 0.1026 - root_mean_squared_error: 0.1652 - val_loss: 0.1294 - val_mean_absolute_error: 0.1037 - val_root_mean_squared_error: 0.1677
# Epoch 29/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1250 - mean_absolute_error: 0.1026 - root_mean_squared_error: 0.1651
# Epoch 29: val_loss improved from 0.12938 to 0.11562, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 29 is 4.210118658127759e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.1250 - mean_absolute_error: 0.1026 - root_mean_squared_error: 0.1652 - val_loss: 0.1156 - val_mean_absolute_error: 0.1037 - val_root_mean_squared_error: 0.1677
# Epoch 30/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1127 - mean_absolute_error: 0.1026 - root_mean_squared_error: 0.1651
# Epoch 30: val_loss improved from 0.11562 to 0.10700, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 30 is 2.5794956639786497e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.1127 - mean_absolute_error: 0.1026 - root_mean_squared_error: 0.1651 - val_loss: 0.1070 - val_mean_absolute_error: 0.1037 - val_root_mean_squared_error: 0.1677
# Epoch 31/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1051 - mean_absolute_error: 0.1026 - root_mean_squared_error: 0.1651
# Epoch 31: val_loss improved from 0.10700 to 0.10210, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 31 is 1.3141179772514343e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.1051 - mean_absolute_error: 0.1026 - root_mean_squared_error: 0.1651 - val_loss: 0.1021 - val_mean_absolute_error: 0.1037 - val_root_mean_squared_error: 0.1677
# Epoch 32/500
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1009 - mean_absolute_error: 0.1026 - root_mean_squared_error: 0.1651
# Epoch 32: val_loss improved from 0.10210 to 0.09985, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 32 is 4.5788590449172533e-07
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.1009 - mean_absolute_error: 0.1026 - root_mean_squared_error: 0.1651 - val_loss: 0.0998 - val_mean_absolute_error: 0.1037 - val_root_mean_squared_error: 0.1677
# Epoch 33/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0991 - mean_absolute_error: 0.1026 - root_mean_squared_error: 0.1651
# Epoch 33: val_loss improved from 0.09985 to 0.09925, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 33 is 4.0505082888021875e-08
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 0.0991 - mean_absolute_error: 0.1026 - root_mean_squared_error: 0.1651 - val_loss: 0.0993 - val_mean_absolute_error: 0.1037 - val_root_mean_squared_error: 0.1677
# Epoch 34/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0966 - mean_absolute_error: 0.1026 - root_mean_squared_error: 0.1651
# Epoch 34: val_loss improved from 0.09925 to 0.06961, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 34 is 2.095631671408027e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0966 - mean_absolute_error: 0.1026 - root_mean_squared_error: 0.1651 - val_loss: 0.0696 - val_mean_absolute_error: 0.1037 - val_root_mean_squared_error: 0.1677
# Epoch 35/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0606 - mean_absolute_error: 0.1026 - root_mean_squared_error: 0.1651
# Epoch 35: val_loss improved from 0.06961 to 0.04192, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 35 is 2.085810662310083e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0606 - mean_absolute_error: 0.1026 - root_mean_squared_error: 0.1651 - val_loss: 0.0419 - val_mean_absolute_error: 0.1038 - val_root_mean_squared_error: 0.1677
# Epoch 36/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0378 - mean_absolute_error: 0.1027 - root_mean_squared_error: 0.1651
# Epoch 36: val_loss improved from 0.04192 to 0.03007, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 36 is 2.066973828925556e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0377 - mean_absolute_error: 0.1027 - root_mean_squared_error: 0.1651 - val_loss: 0.0301 - val_mean_absolute_error: 0.1038 - val_root_mean_squared_error: 0.1676
# Epoch 37/500
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0281 - mean_absolute_error: 0.1027 - root_mean_squared_error: 0.1651
# Epoch 37: val_loss improved from 0.03007 to 0.02522, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 37 is 2.039284905703109e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - loss: 0.0281 - mean_absolute_error: 0.1027 - root_mean_squared_error: 0.1651 - val_loss: 0.0252 - val_mean_absolute_error: 0.1039 - val_root_mean_squared_error: 0.1676
# Epoch 38/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0241 - mean_absolute_error: 0.1028 - root_mean_squared_error: 0.1651
# Epoch 38: val_loss improved from 0.02522 to 0.02335, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 38 is 2.0029845716616263e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 0.0241 - mean_absolute_error: 0.1028 - root_mean_squared_error: 0.1651 - val_loss: 0.0233 - val_mean_absolute_error: 0.1039 - val_root_mean_squared_error: 0.1676
# Epoch 39/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0226 - mean_absolute_error: 0.1028 - root_mean_squared_error: 0.1651
# Epoch 39: val_loss improved from 0.02335 to 0.02266, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 39 is 1.9583883583482224e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0226 - mean_absolute_error: 0.1028 - root_mean_squared_error: 0.1651 - val_loss: 0.0227 - val_mean_absolute_error: 0.1039 - val_root_mean_squared_error: 0.1676
# Epoch 40/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0221 - mean_absolute_error: 0.1028 - root_mean_squared_error: 0.1651
# Epoch 40: val_loss improved from 0.02266 to 0.02243, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 40 is 1.9058839071594228e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0221 - mean_absolute_error: 0.1028 - root_mean_squared_error: 0.1651 - val_loss: 0.0224 - val_mean_absolute_error: 0.1040 - val_root_mean_squared_error: 0.1676
# Epoch 41/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0219 - mean_absolute_error: 0.1029 - root_mean_squared_error: 0.1651
# Epoch 41: val_loss improved from 0.02243 to 0.02235, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 41 is 1.8459275998655727e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0219 - mean_absolute_error: 0.1029 - root_mean_squared_error: 0.1651 - val_loss: 0.0223 - val_mean_absolute_error: 0.1040 - val_root_mean_squared_error: 0.1675
# Epoch 42/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0219 - mean_absolute_error: 0.1029 - root_mean_squared_error: 0.1650
# Epoch 42: val_loss improved from 0.02235 to 0.02232, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 42 is 1.7790405916267898e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 0.0219 - mean_absolute_error: 0.1029 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1040 - val_root_mean_squared_error: 0.1675
# Epoch 43/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218 - mean_absolute_error: 0.1029 - root_mean_squared_error: 0.1650
# Epoch 43: val_loss improved from 0.02232 to 0.02232, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 43 is 1.7058042809824704e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0218 - mean_absolute_error: 0.1029 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1040 - val_root_mean_squared_error: 0.1675
# Epoch 44/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218 - mean_absolute_error: 0.1030 - root_mean_squared_error: 0.1650
# Epoch 44: val_loss improved from 0.02232 to 0.02231, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 44 is 1.6268552561903484e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0218 - mean_absolute_error: 0.1030 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1040 - val_root_mean_squared_error: 0.1675
# Epoch 45/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218 - mean_absolute_error: 0.1030 - root_mean_squared_error: 0.1650
# Epoch 45: val_loss improved from 0.02231 to 0.02231, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 45 is 1.5428797618427532e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0218 - mean_absolute_error: 0.1030 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1041 - val_root_mean_squared_error: 0.1675
# Epoch 46/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218 - mean_absolute_error: 0.1030 - root_mean_squared_error: 0.1650
# Epoch 46: val_loss improved from 0.02231 to 0.02231, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 46 is 1.4546077338576547e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0218 - mean_absolute_error: 0.1030 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1041 - val_root_mean_squared_error: 0.1675
# Epoch 47/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0218 - mean_absolute_error: 0.1030 - root_mean_squared_error: 0.1650
# Epoch 47: val_loss improved from 0.02231 to 0.02231, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 47 is 1.3628064546938096e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 0.0218 - mean_absolute_error: 0.1030 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1041 - val_root_mean_squared_error: 0.1675
# Epoch 48/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218 - mean_absolute_error: 0.1030 - root_mean_squared_error: 0.1650
# Epoch 48: val_loss improved from 0.02231 to 0.02231, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 48 is 1.268273883940474e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0218 - mean_absolute_error: 0.1030 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1041 - val_root_mean_squared_error: 0.1675
# Epoch 49/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218 - mean_absolute_error: 0.1030 - root_mean_squared_error: 0.1650
# Epoch 49: val_loss improved from 0.02231 to 0.02231, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 49 is 1.1718317222538561e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0218 - mean_absolute_error: 0.1030 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1041 - val_root_mean_squared_error: 0.1675
# Epoch 50/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218 - mean_absolute_error: 0.1030 - root_mean_squared_error: 0.1650
# Epoch 50: val_loss improved from 0.02231 to 0.02231, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 50 is 1.0743182689302985e-05
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0218 - mean_absolute_error: 0.1030 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1041 - val_root_mean_squared_error: 0.1675
# Epoch 51/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650
# Epoch 51: val_loss improved from 0.02231 to 0.02231, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 51 is 9.765811351999472e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1041 - val_root_mean_squared_error: 0.1675
# Epoch 52/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650
# Epoch 52: val_loss improved from 0.02231 to 0.02231, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 52 is 8.794698765787714e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1041 - val_root_mean_squared_error: 0.1675
# Epoch 53/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650
# Epoch 53: val_loss improved from 0.02231 to 0.02231, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 53 is 7.838286083203619e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1041 - val_root_mean_squared_error: 0.1675
# Epoch 54/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650
# Epoch 54: val_loss improved from 0.02231 to 0.02230, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 54 is 6.904886681558561e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1041 - val_root_mean_squared_error: 0.1675
# Epoch 55/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650
# Epoch 55: val_loss improved from 0.02230 to 0.02230, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 55 is 6.002613900992587e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1041 - val_root_mean_squared_error: 0.1675
# Epoch 56/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650
# Epoch 56: val_loss improved from 0.02230 to 0.02230, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 56 is 5.13931052130066e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1042 - val_root_mean_squared_error: 0.1675
# Epoch 57/500
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650
# Epoch 57: val_loss improved from 0.02230 to 0.02230, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 57 is 4.322480590536767e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1042 - val_root_mean_squared_error: 0.1675
# Epoch 58/500
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650
# Epoch 58: val_loss improved from 0.02230 to 0.02230, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 58 is 3.559224197958714e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1042 - val_root_mean_squared_error: 0.1675
# Epoch 59/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650
# Epoch 59: val_loss improved from 0.02230 to 0.02230, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 59 is 2.856175758283454e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1042 - val_root_mean_squared_error: 0.1675
# Epoch 60/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650
# Epoch 60: val_loss improved from 0.02230 to 0.02230, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 60 is 2.2194463437014754e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1042 - val_root_mean_squared_error: 0.1675
# Epoch 61/500
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650
# Epoch 61: val_loss improved from 0.02230 to 0.02230, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 61 is 1.6545705649148917e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1042 - val_root_mean_squared_error: 0.1675
# Epoch 62/500
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650
# Epoch 62: val_loss improved from 0.02230 to 0.02230, saving model to models/vit_transformer_final_model.keras
#
# Learning rate for epoch 62 is 1.1664584629223376e-06
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 0.0218 - mean_absolute_error: 0.1031 - root_mean_squared_error: 0.1650 - val_loss: 0.0223 - val_mean_absolute_error: 0.1042 - val_root_mean_squared_error: 0.1675
#
# Training completed.
# Best validation loss: 0.022303 at epoch 62

# %% [markdown]
# ## Make prediction

# %%
from keras.models import load_model
model_saved = load_model('models/vit_transformer_final_model.keras')

# %% [markdown]
# ### Historical

# %%
# Load the CMIP6 raw data (predictor variables)
cmip6_historical = '/data/cristi/a/cristi/downscaled_data/cmip6/raw/zarr/RO_CMIP6_raw/CNRM-ESM2-1/historical/r1i1p1f2/tas/tas_day_CNRM-ESM2-1_historical_r1i1p1f2_gr_1950_2014_rou.zarr'
cmip6_historical = xr.open_zarr(cmip6_historical)
cmip6_historical_high_res = cmip6_historical.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
# Get the mean and std from the training set for denormalization
cmip6_historical_tas_min = cmip6_historical_high_res['tas'].min().values
cmip6_historical_tas_max = cmip6_historical_high_res['tas'].max().values
cmip6_historical_norm = normalize(cmip6_historical_high_res['tas'])
cmip6_historical_norm = cmip6_historical_norm.values
cmip6_historical_norm_reshaped = cmip6_historical_norm[..., np.newaxis]


cmip6_historical_pr = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/historical/r1i1p1f2/pr/pr_day_CNRM-ESM2-1_historical_r1i1p1f2_gr_1950_2014_rou.zarr'
cmip6_historical_pr = xr.open_zarr(cmip6_historical_pr)
cmip6_historical_pr = cmip6_historical_pr * 86400
cmip6_historical_pr_high_res = cmip6_historical_pr.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_historical_pr_high_res['pr'] = xr.where(cmip6_historical_pr_high_res['pr'] < 0, 0, cmip6_historical_pr_high_res['pr'])

cmip6_historical_pr_high_res_log1p = cmip6_historical_pr_high_res.copy()  # Make a copy to avoid modifying the original dataset
cmip6_historical_pr_high_res_log1p = xr.apply_ufunc(np.log1p, cmip6_historical_pr_high_res_log1p  ,dask="parallelized", output_dtypes=[float])
cmip6_historical_pr_min = cmip6_historical_pr_high_res_log1p['pr'].min().values
cmip6_historical_pr_max = cmip6_historical_pr_high_res_log1p['pr'].max().values

cmip6_historical_pr_norm_log1p = normalize(cmip6_historical_pr_high_res_log1p ['pr'])
cmip6_historical_pr_norm_log1p = cmip6_historical_pr_norm_log1p.values
cmip6_historical_pr_norm_log1p_reshaped = cmip6_historical_pr_norm_log1p[..., np.newaxis]

cmip6_historical_psl = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/historical/r1i1p1f2/psl/psl_day_CNRM-ESM2-1_historical_r1i1p1f2_gr_1950_2014_rou.zarr'
cmip6_historical_psl = xr.open_zarr(cmip6_historical_psl)
cmip6_historical_psl_high_res = cmip6_historical_psl.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_historical_psl_norm = normalize(cmip6_historical_psl_high_res['psl'])
cmip6_historical_psl_norm = cmip6_historical_psl_norm.values
cmip6_historical_psl_norm_reshaped = cmip6_historical_psl_norm[..., np.newaxis]

elev_dif_norm_final = np.repeat(elev_dif_norm[np.newaxis :, :], len(cmip6_historical_norm_reshaped), axis=0)
elev_dif_norm_final = elev_dif_norm_final[..., np.newaxis]

# Concatenate the reshaped arrays along the last axis
cmip6_scen_combined = np.concatenate((cmip6_historical_norm_reshaped, cmip6_historical_pr_norm_log1p_reshaped, cmip6_historical_psl_norm_reshaped, elev_dif_norm_final), axis=-1)
# Predict downscaled high-resolution data
X_scen = create_temporal_sequences_centered(cmip6_scen_combined, window_size) 
predicted_high_res = model_saved.predict(X_scen)

# temperature
predicted_high_res_tas = cmip6_historical_norm_reshaped +  predicted_high_res[:,window_size,:,:,:1]
# Back-transform the predictions and actual values
predicted_high_res_denorm = predicted_high_res_tas * (cmip6_historical_tas_max- cmip6_historical_tas_min) + cmip6_historical_tas_min
# Reshape the predictions to match the original GMFD resolution
predicted_high_res_final = predicted_high_res_denorm.reshape(cmip6_historical_high_res['tas'].shape)
# Save the predictions to a NetCDF file
predicted_tas = xr.DataArray(predicted_high_res_final, dims=cmip6_historical_high_res['tas'].dims, coords=cmip6_historical_high_res['tas'].coords, name='tas_downscaled')
predicted_tas.to_netcdf('/data/keeling/a/ad87/downscale/ncs/vit/predicted_high_res_tas_vit.nc')
# #### Results saved to NetCDF format
print("Downscaled high-resolution predictions saved to NetCDF format.")

# precipitation
predicted_high_res_pr = cmip6_historical_pr_norm_log1p_reshaped  +  predicted_high_res[:,window_size,:,:,1:2]
# Back-transform the predictions and actual values
predicted_high_res_denorm = predicted_high_res_pr * (cmip6_historical_pr_max - cmip6_historical_pr_min) + cmip6_historical_pr_min
predicted_high_res_denorm_back = np.expm1(predicted_high_res_denorm)
predicted_high_res_denorm_back[predicted_high_res_denorm_back < 0] = 0 # Replace negative values with 0

# Reshape the predictions to match the original GMFD resolution
predicted_high_res_final = predicted_high_res_denorm_back.reshape(cmip6_historical_high_res['tas'].shape)
# Save the predictions to a NetCDF file
predicted_pr = xr.DataArray(predicted_high_res_final, dims=cmip6_historical_high_res['tas'].dims, coords=cmip6_historical_high_res['tas'].coords, name='pr_downscaled')
predicted_pr.to_netcdf('/data/keeling/a/ad87/downscale/ncs/vit/predicted_high_res_pr_vit.nc')
# #### Results saved to NetCDF format
print("Downscaled high-resolution predictions saved to NetCDF format.")
# Out:
# 742/742 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step
# Downscaled high-resolution predictions saved to NetCDF format.
# Downscaled high-resolution predictions saved to NetCDF format.

# %% [markdown]
# ### Scenario data

# %% [markdown]
# #### SSP 126

# %%
# Load the CMIP6 raw data (predictor variables)
cmip6_ssp126 = '/data/cristi/a/cristi/downscaled_data/cmip6/raw/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp126/r1i1p1f2/tas/tas_day_CNRM-ESM2-1_ssp126_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_ssp126 = xr.open_zarr(cmip6_ssp126)
cmip6_sp126_high_res = cmip6_ssp126.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
# Get the mean and std from the training set for denormalization
cmip6_sp126_tas_min = cmip6_sp126_high_res['tas'].min().values
cmip6_sp126_tas_max = cmip6_sp126_high_res['tas'].max().values
cmip6_sp126_norm = normalize(cmip6_sp126_high_res['tas'])
cmip6_sp126_norm = cmip6_sp126_norm.values
cmip6_sp126_norm_reshaped = cmip6_sp126_norm[..., np.newaxis]


cmip6_sp126_pr = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp126/r1i1p1f2/pr/pr_day_CNRM-ESM2-1_ssp126_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_sp126_pr = xr.open_zarr(cmip6_sp126_pr)
cmip6_sp126_pr = cmip6_sp126_pr * 86400
cmip6_sp126_pr_high_res = cmip6_sp126_pr.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_sp126_pr_high_res['pr'] = xr.where(cmip6_sp126_pr_high_res['pr'] < 0, 0, cmip6_sp126_pr_high_res['pr'])

cmip6_sp126_pr_high_res_log1p = cmip6_sp126_pr_high_res.copy()  # Make a copy to avoid modifying the original dataset
cmip6_sp126_pr_high_res_log1p = xr.apply_ufunc(np.log1p, cmip6_sp126_pr_high_res_log1p  ,dask="parallelized", output_dtypes=[float])
cmip6_sp126_pr_min = cmip6_sp126_pr_high_res_log1p['pr'].min().values
cmip6_sp126_pr_max = cmip6_sp126_pr_high_res_log1p['pr'].max().values

cmip6_sp126_pr_norm_log1p = normalize(cmip6_sp126_pr_high_res_log1p ['pr'])
cmip6_sp126_pr_norm_log1p = cmip6_sp126_pr_norm_log1p.values
cmip6_sp126_pr_norm_log1p_reshaped = cmip6_sp126_pr_norm_log1p[..., np.newaxis]

cmip6_sp126_psl = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp126/r1i1p1f2/psl/psl_day_CNRM-ESM2-1_ssp126_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_sp126_psl = xr.open_zarr(cmip6_sp126_psl)
cmip6_sp126_psl_high_res = cmip6_sp126_psl.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_sp126_psl_norm = normalize(cmip6_sp126_psl_high_res['psl'])
cmip6_sp126_psl_norm = cmip6_sp126_psl_norm.values
cmip6_sp126_psl_norm_reshaped = cmip6_sp126_psl_norm[..., np.newaxis]

elev_dif_norm_final = np.repeat(elev_dif_norm[np.newaxis :, :], len(cmip6_sp126_norm_reshaped ), axis=0)
elev_dif_norm_final = elev_dif_norm_final[..., np.newaxis]


# Concatenate the reshaped arrays along the last axis
cmip6_scen_combined = np.concatenate((cmip6_sp126_norm_reshaped, cmip6_sp126_pr_norm_log1p_reshaped, cmip6_sp126_psl_norm_reshaped, elev_dif_norm_final), axis=-1)
# Predict downscaled high-resolution data
X_scen = create_temporal_sequences_centered(cmip6_scen_combined, window_size) 
predicted_high_res = model_saved.predict(X_scen)

# temperature
predicted_high_res_tas = cmip6_sp126_norm_reshaped +  predicted_high_res[:,window_size,:,:,:1]
# Back-transform the predictions and actual values
predicted_high_res_denorm = predicted_high_res_tas * (cmip6_sp126_tas_max- cmip6_sp126_tas_min) + cmip6_sp126_tas_min
# Reshape the predictions to match the original GMFD resolution
predicted_high_res_final = predicted_high_res_denorm.reshape(cmip6_sp126_high_res['tas'].shape)
# Save the predictions to a NetCDF file
predicted_tas = xr.DataArray(predicted_high_res_final, dims=cmip6_sp126_high_res['tas'].dims, coords=cmip6_sp126_high_res['tas'].coords, name='tas_downscaled')
predicted_tas.to_netcdf('/data/keeling/a/ad87/downscale/ncs/vit/predicted_high_res_tas_vit_ssp126.nc')
# #### Results saved to NetCDF format
print("Downscaled high-resolution predictions saved to NetCDF format.")

# precipitation
predicted_high_res_pr = cmip6_sp126_pr_norm_log1p_reshaped  +  predicted_high_res[:,window_size,:,:,1:2]
# Back-transform the predictions and actual values
predicted_high_res_denorm = predicted_high_res_pr * (cmip6_sp126_pr_max - cmip6_sp126_pr_min) + cmip6_sp126_pr_min
predicted_high_res_denorm_back = np.expm1(predicted_high_res_denorm)
predicted_high_res_denorm_back[predicted_high_res_denorm_back < 0] = 0 # Replace negative values with 0

# Reshape the predictions to match the original GMFD resolution
predicted_high_res_final = predicted_high_res_denorm_back.reshape(cmip6_sp126_high_res['tas'].shape)
# Save the predictions to a NetCDF file
predicted_pr = xr.DataArray(predicted_high_res_final, dims=cmip6_sp126_high_res['tas'].dims, coords=cmip6_sp126_high_res['tas'].coords, name='pr_downscaled')
predicted_pr.to_netcdf('/data/keeling/a/ad87/downscale/ncs/vit/predicted_high_res_pr_vit_ssp126.nc')
# #### Results saved to NetCDF format
print("Downscaled high-resolution predictions saved to NetCDF format.")
# Out:
# 982/982 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step
# Downscaled high-resolution predictions saved to NetCDF format.
# Downscaled high-resolution predictions saved to NetCDF format.

# %%
predicted_high_res_denorm[predicted_high_res_denorm < 0] = 0
predicted_high_res_denorm.min()
# Out:
# 0.0

# %%
predicted_pr.isel(time=5000).plot()

# %%
gmfd_pr['prcp'].isel(time=5000).plot() # Use .compute() if using Dask

# %%
cmip6_sp126_pr['pr'].isel(time=5000).plot()  # Use .compute() if using Dask

# %% [markdown]
# #### SSP 245

# %%
# Load the CMIP6 raw data (predictor variables)
cmip6_ssp245 = '/data/cristi/a/cristi/downscaled_data/cmip6/raw/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp245/r1i1p1f2/tas/tas_day_CNRM-ESM2-1_ssp245_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_ssp245 = xr.open_zarr(cmip6_ssp245)
cmip6_sp245_high_res = cmip6_ssp245.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
# Get the mean and std from the training set for denormalization
cmip6_sp245_tas_min = cmip6_sp245_high_res['tas'].min().values
cmip6_sp245_tas_max = cmip6_sp245_high_res['tas'].max().values
cmip6_sp245_norm = normalize(cmip6_sp245_high_res['tas'])
cmip6_sp245_norm = cmip6_sp245_norm.values
cmip6_sp245_norm_reshaped = cmip6_sp245_norm[..., np.newaxis]


cmip6_sp245_pr = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp245/r1i1p1f2/pr/pr_day_CNRM-ESM2-1_ssp245_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_sp245_pr = xr.open_zarr(cmip6_sp245_pr)
cmip6_sp245_pr = cmip6_sp245_pr * 86400
cmip6_sp245_pr_high_res = cmip6_sp245_pr.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_sp245_pr_high_res['pr'] = xr.where(cmip6_sp245_pr_high_res['pr'] < 0, 0, cmip6_sp245_pr_high_res['pr'])

cmip6_sp245_pr_high_res_log1p = cmip6_sp245_pr_high_res.copy()  # Make a copy to avoid modifying the original dataset
cmip6_sp245_pr_high_res_log1p = xr.apply_ufunc(np.log1p, cmip6_sp245_pr_high_res_log1p  ,dask="parallelized", output_dtypes=[float])
cmip6_sp245_pr_min = cmip6_sp245_pr_high_res_log1p['pr'].min().values
cmip6_sp245_pr_max = cmip6_sp245_pr_high_res_log1p['pr'].max().values

cmip6_sp245_pr_norm_log1p = normalize(cmip6_sp245_pr_high_res_log1p ['pr'])
cmip6_sp245_pr_norm_log1p = cmip6_sp245_pr_norm_log1p.values
cmip6_sp245_pr_norm_log1p_reshaped = cmip6_sp245_pr_norm_log1p[..., np.newaxis]

cmip6_sp245_psl = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp245/r1i1p1f2/psl/psl_day_CNRM-ESM2-1_ssp245_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_sp245_psl = xr.open_zarr(cmip6_sp245_psl)
cmip6_sp245_psl_high_res = cmip6_sp245_psl.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_sp245_psl_norm = normalize(cmip6_sp245_psl_high_res['psl'])
cmip6_sp245_psl_norm = cmip6_sp245_psl_norm.values
cmip6_sp245_psl_norm_reshaped = cmip6_sp245_psl_norm[..., np.newaxis]

elev_dif_norm_final = np.repeat(elev_dif_norm[np.newaxis :, :], len(cmip6_sp245_psl_norm_reshaped ), axis=0)
elev_dif_norm_final = elev_dif_norm_final[..., np.newaxis]


# Concatenate the reshaped arrays along the last axis
cmip6_scen_combined = np.concatenate((cmip6_sp245_norm_reshaped, cmip6_sp245_pr_norm_log1p_reshaped, cmip6_sp245_psl_norm_reshaped, elev_dif_norm_final), axis=-1)
# Predict downscaled high-resolution data
X_scen = create_temporal_sequences_centered(cmip6_scen_combined, window_size) 
predicted_high_res = model_saved.predict(X_scen)

# temperature
predicted_high_res_tas = cmip6_sp245_norm_reshaped +  predicted_high_res[:,window_size,:,:,:1]
# Back-transform the predictions and actual values
predicted_high_res_denorm = predicted_high_res_tas * (cmip6_sp245_tas_max- cmip6_sp245_tas_min) + cmip6_sp245_tas_min
# Reshape the predictions to match the original GMFD resolution
predicted_high_res_final = predicted_high_res_denorm.reshape(cmip6_sp245_high_res['tas'].shape)
# Save the predictions to a NetCDF file
predicted_tas = xr.DataArray(predicted_high_res_final, dims=cmip6_sp245_high_res['tas'].dims, coords=cmip6_sp245_high_res['tas'].coords, name='tas_downscaled')
predicted_tas.to_netcdf('/data/keeling/a/ad87/downscale/ncs/vit/predicted_high_res_tas_vit_ssp245.nc')
# #### Results saved to NetCDF format
print("Downscaled high-resolution predictions saved to NetCDF format.")

# precipitation
predicted_high_res_pr = cmip6_sp245_pr_norm_log1p_reshaped  +  predicted_high_res[:,window_size,:,:,1:2]
# Back-transform the predictions and actual values
predicted_high_res_denorm = predicted_high_res_pr * (cmip6_sp245_pr_max - cmip6_sp245_pr_min) + cmip6_sp245_pr_min
predicted_high_res_denorm_back = np.expm1(predicted_high_res_denorm)
predicted_high_res_denorm_back[predicted_high_res_denorm_back < 0] = 0 # Replace negative values with 0

# Reshape the predictions to match the original GMFD resolution
predicted_high_res_final = predicted_high_res_denorm_back.reshape(cmip6_sp245_high_res['tas'].shape)
# Save the predictions to a NetCDF file
predicted_pr = xr.DataArray(predicted_high_res_final, dims=cmip6_sp245_high_res['tas'].dims, coords=cmip6_sp245_high_res['tas'].coords, name='pr_downscaled')
predicted_pr.to_netcdf('/data/keeling/a/ad87/downscale/ncs/vit/predicted_high_res_pr_vit_ssp245.nc')
# #### Results saved to NetCDF format
print("Downscaled high-resolution predictions saved to NetCDF format.")
# Out:
# 982/982 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step
# Downscaled high-resolution predictions saved to NetCDF format.
# Downscaled high-resolution predictions saved to NetCDF format.

# %% [markdown]
# #### SSP 585

# %%
# Load the CMIP6 raw data (predictor variables)
cmip6_ssp585 = '/data/cristi/a/cristi/downscaled_data/cmip6/raw/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp585/r1i1p1f2/tas/tas_day_CNRM-ESM2-1_ssp585_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_ssp585 = xr.open_zarr(cmip6_ssp585)
cmip6_sp585_high_res = cmip6_ssp585.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
# Get the mean and std from the training set for denormalization
cmip6_sp585_tas_min = cmip6_sp585_high_res['tas'].min().values
cmip6_sp585_tas_max = cmip6_sp585_high_res['tas'].max().values
cmip6_sp585_norm = normalize(cmip6_sp585_high_res['tas'])
cmip6_sp585_norm = cmip6_sp585_norm.values
cmip6_sp585_norm_reshaped = cmip6_sp585_norm[..., np.newaxis]


cmip6_sp585_pr = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp585/r1i1p1f2/pr/pr_day_CNRM-ESM2-1_ssp585_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_sp585_pr = xr.open_zarr(cmip6_sp585_pr)
cmip6_sp585_pr = cmip6_sp585_pr * 86400
cmip6_sp585_pr_high_res = cmip6_sp585_pr.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_sp585_pr_high_res['pr'] = xr.where(cmip6_sp585_pr_high_res['pr'] < 0, 0, cmip6_sp585_pr_high_res['pr'])

cmip6_sp585_pr_high_res_log1p = cmip6_sp585_pr_high_res.copy()  # Make a copy to avoid modifying the original dataset
cmip6_sp585_pr_high_res_log1p = xr.apply_ufunc(np.log1p, cmip6_sp585_pr_high_res_log1p  ,dask="parallelized", output_dtypes=[float])
cmip6_sp585_pr_min = cmip6_sp585_pr_high_res_log1p['pr'].min().values
cmip6_sp585_pr_max = cmip6_sp585_pr_high_res_log1p['pr'].max().values

cmip6_sp585_pr_norm_log1p = normalize(cmip6_sp585_pr_high_res_log1p ['pr'])
cmip6_sp585_pr_norm_log1p = cmip6_sp585_pr_norm_log1p.values
cmip6_sp585_pr_norm_log1p_reshaped = cmip6_sp585_pr_norm_log1p[..., np.newaxis]

cmip6_sp585_psl = '/data/keeling/a/ad87/cmip6/zarr/RO_CMIP6_raw/CNRM-ESM2-1/ssp585/r1i1p1f2/psl/psl_day_CNRM-ESM2-1_ssp585_r1i1p1f2_gr_2015_2100_rou.zarr'
cmip6_sp585_psl = xr.open_zarr(cmip6_sp585_psl)
cmip6_sp585_psl_high_res = cmip6_sp585_psl.interp(lat=target_lat, lon=target_lon, method='cubic', kwargs={"fill_value": "extrapolate"})
cmip6_sp585_psl_norm = normalize(cmip6_sp585_psl_high_res['psl'])
cmip6_sp585_psl_norm = cmip6_sp585_psl_norm.values
cmip6_sp585_psl_norm_reshaped = cmip6_sp585_psl_norm[..., np.newaxis]

elev_dif_norm_final = np.repeat(elev_dif_norm[np.newaxis :, :], len(cmip6_sp585_psl_norm), axis=0)
elev_dif_norm_final = elev_dif_norm_final[..., np.newaxis]


# Concatenate the reshaped arrays along the last axis
cmip6_scen_combined = np.concatenate((cmip6_sp585_norm_reshaped, cmip6_sp585_pr_norm_log1p_reshaped, cmip6_sp585_psl_norm_reshaped, elev_dif_norm_final), axis=-1)
# Predict downscaled high-resolution data
X_scen = create_temporal_sequences_centered(cmip6_scen_combined, window_size) 
predicted_high_res = model_saved.predict(X_scen)

# temperature
predicted_high_res_tas = cmip6_sp585_norm_reshaped +  predicted_high_res[:,window_size,:,:,:1]
# Back-transform the predictions and actual values
predicted_high_res_denorm = predicted_high_res_tas * (cmip6_sp585_tas_max- cmip6_sp585_tas_min) + cmip6_sp585_tas_min
# Reshape the predictions to match the original GMFD resolution
predicted_high_res_final = predicted_high_res_denorm.reshape(cmip6_sp585_high_res['tas'].shape)
# Save the predictions to a NetCDF file
predicted_tas = xr.DataArray(predicted_high_res_final, dims=cmip6_sp585_high_res['tas'].dims, coords=cmip6_sp585_high_res['tas'].coords, name='tas_downscaled')
predicted_tas.to_netcdf('/data/keeling/a/ad87/downscale/ncs/vit/predicted_high_res_tas_vit_ssp585.nc')
# #### Results saved to NetCDF format
print("Downscaled high-resolution predictions saved to NetCDF format.")

# precipitation
predicted_high_res_pr = cmip6_sp585_pr_norm_log1p_reshaped  +  predicted_high_res[:,window_size,:,:,1:2]
# Back-transform the predictions and actual values
predicted_high_res_denorm = predicted_high_res_pr * (cmip6_sp585_pr_max - cmip6_sp585_pr_min) + cmip6_sp585_pr_min
predicted_high_res_denorm_back = np.expm1(predicted_high_res_denorm)
predicted_high_res_denorm_back[predicted_high_res_denorm_back < 0] = 0 # Replace negative values with 0

# Reshape the predictions to match the original GMFD resolution
predicted_high_res_final = predicted_high_res_denorm_back.reshape(cmip6_sp585_high_res['tas'].shape)
# Save the predictions to a NetCDF file
predicted_pr = xr.DataArray(predicted_high_res_final, dims=cmip6_sp585_high_res['tas'].dims, coords=cmip6_sp585_high_res['tas'].coords, name='pr_downscaled')
predicted_pr.to_netcdf('/data/keeling/a/ad87/downscale/ncs/vit/predicted_high_res_pr_vit_ssp585.nc')
# #### Results saved to NetCDF format
print("Downscaled high-resolution predictions saved to NetCDF format.")
# Out:
# 982/982 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step
# Downscaled high-resolution predictions saved to NetCDF format.
# Downscaled high-resolution predictions saved to NetCDF format.

# %%
import graphviz

dot = graphviz.Digraph(format='png')
dot.attr(rankdir='TB', size="8,10")

dot.attr('node', shape='box', style='filled', fillcolor="#E0E5E8", fontname="Helvetica")

dot.node('Input', 'Input\n(7, 42, 97, 4)')

dot.node('Embedding', '''Residual Multi-Scale Patch Embedding
- 3D Conv (3x3x3, 4x4x4, 5x5x5)
- Fusion Conv3D (1x1x1)
- Residual Projection (1x1x1)
- Reshape to Sequence (patches, 320)''')

dot.node('PosEnc', 'Fourier Positional Encoding\n(sin/cos encoding)')

dot.node('Transformer', '''Spatial-Temporal Transformer Blocks
(6 layers)
- Multi-Head Attention (8 heads, key dim=40)
- Residual + Layer Norm
- MLP (Dense 512, GELU, Dropout)''')

dot.node('Reshape', 'Reshape to Temporal Sequence\n(7, Spatial_Patches x 320)')

dot.node('TDense', '''TimeDistributed Dense Layers
- Dense (256, GELU) + Dropout
- Dense (42×97×2, Linear)
- Reshape to (42, 97, 2)''')

dot.node('Output', 'Output\n(7, 42, 97, 2)')

dot.edges([
    ('Input', 'Embedding'),
    ('Embedding', 'PosEnc'),
    ('PosEnc', 'Transformer'),
    ('Transformer', 'Reshape'),
    ('Reshape', 'TDense'),
    ('TDense', 'Output')
])

# Save and display the diagram
dot.render('vit_model_diagram', view=False)
# Out:
# 'vit_model_diagram.png'
